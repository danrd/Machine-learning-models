# %% [markdown]
# # Тематическая классификация длинных текстов - TFIDF и LogReg

# %%
import warnings
warnings.filterwarnings('ignore')

from sklearn.datasets import fetch_20newsgroups
from sklearn.metrics import accuracy_score

import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import collections

import torch
from torch import nn
from torch.nn import functional as F

import dlnlputils
from dlnlputils.data import tokenize_text_simple_regex, tokenize_corpus, build_vocabulary, \
    vectorize_texts, SparseFeaturesDataset
from dlnlputils.pipeline import train_eval_loop, predict_with_model, init_random_seed

init_random_seed()

# %% [markdown]
# ## Предобработка текстов и подготовка признаков

# %%
train_source = fetch_20newsgroups(subset='train')
test_source = fetch_20newsgroups(subset='test')

print('Количество обучающих текстов', len(train_source['data']))
print('Количество тестовых текстов', len(test_source['data']))
print()
print(train_source['data'][0].strip())

print()
print('Метка', train_source['target'][0])
# Out:
# Количество обучающих текстов 11314
# Количество тестовых текстов 7532
#
# From: lerxst@wam.umd.edu (where's my thing)
# Subject: WHAT car is this!?
# Nntp-Posting-Host: rac3.wam.umd.edu
# Organization: University of Maryland, College Park
# Lines: 15
#
#  I was wondering if anyone out there could enlighten me on this car I saw
# the other day. It was a 2-door sports car, looked to be from the late 60s/
# early 70s. It was called a Bricklin. The doors were really small. In addition,
# the front bumper was separate from the rest of the body. This is
# all I know. If anyone can tellme a model name, engine specs, years
# of production, where this car is made, history, or whatever info you
# have on this funky looking car, please e-mail.
#
# Thanks,
# - IL
#    ---- brought to you by your neighborhood Lerxst ----
#
# Метка 7

# %% [markdown]
# ### Подготовка признаков

# %%
train_tokenized = tokenize_corpus(train_source['data'])
test_tokenized = tokenize_corpus(test_source['data'])

print(' '.join(train_tokenized[0]))
# Out:
# from lerxst where thing subject what this nntp posting host rac3 organization university maryland college park lines wondering anyone there could enlighten this other door sports looked from late early called bricklin doors were really small addition front bumper separate from rest body this know anyone tellme model name engine specs years production where this made history whatever info have this funky looking please mail thanks brought your neighborhood lerxst

# %%
train_tokenized
# Out:
# [['from',
#   'lerxst',
#   'where',
#   'thing',
#   'subject',
#   'what',
#   'this',
#   'nntp',
#   'posting',
#   'host',
#   'rac3',
#   'organization',
#   'university',
#   'maryland',
#   'college',
#   'park',
#   'lines',
#   'wondering',
#   'anyone',
#   'there',
#   'could',
#   'enlighten',
#   'this',
#   'other',
#   'door',
#   'sports',
#   'looked',
#   'from',
#   'late',
#   'early',
#   'called',
#   'bricklin',
#   'doors',
#   'were',
#   'really',
#   'small',
#   'addition',
#   'front',
#   'bumper',
#   'separate',
#   'from',
#   'rest',
#   'body',
#   'this',
#   'know',
#   'anyone',
#   'tellme',
#   'model',
#   'name',
#   'engine',
#   'specs',
#   'years',
#   'production',
#   'where',
#   'this',
#   'made',
#   'history',
#   'whatever',
#   'info',
#   'have',
#   'this',
#   'funky',
#   'looking',
#   'please',
#   'mail',
#   'thanks',
#   'brought',
#   'your',
#   'neighborhood',
#   'lerxst'],
#  ['from',
#   'guykuo',
#   'carson',
#   'washington',
#   'subject',
#   'clock',
#   'poll',
#   'final',
#   'call',
#   'summary',
#   'final',
#   'call',
#   'clock',
#   'reports',
#   'keywords',
#   'acceleration',
#   'clock',
#   'upgrade',
#   'article',
#   'shelley',
#   '1qvfo9innc3s',
#   'organization',
#   'university',
#   'washington',
#   'lines',
#   'nntp',
#   'posting',
#   'host',
#   'carson',
#   'washington',
#   'fair',
#   'number',
#   'brave',
#   'souls',
#   'upgraded',
#   'their',
#   'clock',
#   'oscillator',
#   'have',
#   'shared',
#   'their',
#   'experiences',
#   'this',
#   'poll',
#   'please',
#   'send',
#   'brief',
#   'message',
#   'detailing',
#   'your',
#   'experiences',
#   'with',
#   'procedure',
#   'speed',
#   'attained',
#   'rated',
#   'speed',
#   'cards',
#   'adapters',
#   'heat',
#   'sinks',
#   'hour',
#   'usage',
#   'floppy',
#   'disk',
#   'functionality',
#   'with',
#   'floppies',
#   'especially',
#   'requested',
#   'will',
#   'summarizing',
#   'next',
#   'days',
#   'please',
#   'network',
#   'knowledge',
#   'base',
#   'have',
#   'done',
#   'clock',
#   'upgrade',
#   'haven',
#   'answered',
#   'this',
#   'poll',
#   'thanks',
#   'guykuo',
#   'washington'],
#  ['from',
#   'twillis',
#   'purdue',
#   'thomas',
#   'willis',
#   'subject',
#   'questions',
#   'organization',
#   'purdue',
#   'university',
#   'engineering',
#   'computer',
#   'network',
#   'distribution',
#   'lines',
#   'well',
#   'folks',
#   'plus',
#   'finally',
#   'gave',
#   'ghost',
#   'this',
#   'weekend',
#   'after',
#   'starting',
#   'life',
#   '512k',
#   'back',
#   '1985',
#   'sooo',
#   'market',
#   'machine',
#   'sooner',
#   'than',
#   'intended',
#   'looking',
#   'into',
#   'picking',
#   'powerbook',
#   'maybe',
#   'have',
#   'bunch',
#   'questions',
#   'that',
#   'hopefully',
#   'somebody',
#   'answer',
#   'does',
#   'anybody',
#   'know',
#   'dirt',
#   'when',
#   'next',
#   'round',
#   'powerbook',
#   'introductions',
#   'expected',
#   'heard',
#   '185c',
#   'supposed',
#   'make',
#   'appearence',
#   'this',
#   'summer',
#   'haven',
#   'heard',
#   'anymore',
#   'since',
#   'have',
#   'access',
#   'macleak',
#   'wondering',
#   'anybody',
#   'there',
#   'more',
#   'info',
#   'anybody',
#   'heard',
#   'rumors',
#   'about',
#   'price',
#   'drops',
#   'powerbook',
#   'line',
#   'like',
#   'ones',
#   'just',
#   'went',
#   'through',
#   'recently',
#   'what',
#   'impression',
#   'display',
#   'could',
#   'probably',
#   'swing',
#   '80mb',
#   'disk',
#   'rather',
#   'than',
#   'really',
#   'have',
#   'feel',
#   'much',
#   'better',
#   'display',
#   'looks',
#   'great',
#   'store',
#   'that',
#   'really',
#   'that',
#   'good',
#   'could',
#   'solicit',
#   'some',
#   'opinions',
#   'people',
#   'worth',
#   'taking',
#   'disk',
#   'size',
#   'money',
#   'active',
#   'display',
#   'realize',
#   'this',
#   'real',
#   'subjective',
#   'question',
#   'only',
#   'played',
#   'around',
#   'with',
#   'machines',
#   'computer',
#   'store',
#   'breifly',
#   'figured',
#   'opinions',
#   'somebody',
#   'actually',
#   'uses',
#   'machine',
#   'daily',
#   'might',
#   'prove',
#   'helpful',
#   'well',
#   'does',
#   'hellcats',
#   'perform',
#   'thanks',
#   'bunch',
#   'advance',
#   'info',
#   'could',
#   'email',
#   'post',
#   'summary',
#   'news',
#   'reading',
#   'time',
#   'premium',
#   'with',
#   'finals',
#   'just',
#   'around',
#   'corner',
#   'willis',
#   'twillis',
#   'purdue',
#   'purdue',
#   'electrical',
#   'engineering',
#   'convictions',
#   'more',
#   'dangerous',
#   'enemies',
#   'truth',
#   'than',
#   'lies',
#   'nietzsche'],
#  ['from',
#   'jgreen',
#   'amber',
#   'green',
#   'subject',
#   'weitek',
#   'p9000',
#   'organization',
#   'harris',
#   'computer',
#   'systems',
#   'division',
#   'lines',
#   'distribution',
#   'world',
#   'nntp',
#   'posting',
#   'host',
#   'amber',
#   'harris',
#   'newsreader',
#   'version',
#   'robert',
#   'kyanko',
#   'rjck',
#   'uucp',
#   'wrote',
#   'abraxis',
#   'iastate',
#   'writes',
#   'article',
#   'abraxis',
#   '734340159',
#   'class1',
#   'iastate',
#   'anyone',
#   'know',
#   'about',
#   'weitek',
#   'p9000',
#   'graphics',
#   'chip',
#   'level',
#   'stuff',
#   'goes',
#   'looks',
#   'pretty',
#   'nice',
#   'this',
#   'quadrilateral',
#   'fill',
#   'command',
#   'that',
#   'requires',
#   'just',
#   'four',
#   'points',
#   'have',
#   'weitek',
#   'address',
#   'phone',
#   'number',
#   'like',
#   'some',
#   'information',
#   'about',
#   'this',
#   'chip',
#   'green',
#   'harris',
#   'corporation',
#   'jgreen',
#   'harris',
#   'computer',
#   'systems',
#   'division',
#   'only',
#   'thing',
#   'that',
#   'really',
#   'scares',
#   'person',
#   'with',
#   'sense',
#   'humor',
#   'jonathan',
#   'winters'],
#  ['from',
#   'head',
#   'harvard',
#   'jonathan',
#   'mcdowell',
#   'subject',
#   'shuttle',
#   'launch',
#   'question',
#   'organization',
#   'smithsonian',
#   'astrophysical',
#   'observatory',
#   'cambridge',
#   'distribution',
#   'lines',
#   'from',
#   'article',
#   'c5owcb',
#   'world',
#   'tombaker',
#   'world',
#   'baker',
#   'article',
#   'c5jlwx',
#   'etrat',
#   'ttacs1',
#   'pack',
#   'writes',
#   'clear',
#   'caution',
#   'warning',
#   'memory',
#   'verify',
#   'unexpected',
#   'errors',
#   'wondering',
#   'what',
#   'expected',
#   'error',
#   'might',
#   'sorry',
#   'this',
#   'really',
#   'dumb',
#   'question',
#   'parity',
#   'errors',
#   'memory',
#   'previously',
#   'known',
#   'conditions',
#   'that',
#   'were',
#   'waivered',
#   'that',
#   'error',
#   'already',
#   'knew',
#   'about',
#   'curious',
#   'what',
#   'real',
#   'meaning',
#   'quote',
#   'understanding',
#   'that',
#   'expected',
#   'errors',
#   'basically',
#   'known',
#   'bugs',
#   'warning',
#   'system',
#   'software',
#   'things',
#   'checked',
#   'that',
#   'have',
#   'right',
#   'values',
#   'because',
#   'they',
#   'aren',
#   'till',
#   'after',
#   'launch',
#   'suchlike',
#   'rather',
#   'than',
#   'code',
#   'possibly',
#   'introduce',
#   'bugs',
#   'they',
#   'just',
#   'tell',
#   'crew',
#   'warning',
#   'before',
#   'liftoff',
#   'ignore',
#   'jonathan'],
#  ['from',
#   'vttoulu',
#   'foxvog',
#   'douglas',
#   'subject',
#   'rewording',
#   'second',
#   'amendment',
#   'ideas',
#   'organization',
#   'lines',
#   'article',
#   '1r1eu1',
#   'transfer',
#   'stratus',
#   'stratus',
#   'tavares',
#   'writes',
#   'article',
#   '1993apr20',
#   '083057',
#   '16899',
#   'ousrvr',
#   'oulu',
#   'vttoulu',
#   'foxvog',
#   'douglas',
#   'writes',
#   'article',
#   '1qv87v',
#   'transfer',
#   'stratus',
#   'stratus',
#   'tavares',
#   'writes',
#   'article',
#   'c5n3gi',
#   'ulowell',
#   'ulowell',
#   'jrutledg',
#   'ulowell',
#   'john',
#   'lawrence',
#   'rutledge',
#   'writes',
#   'massive',
#   'destructive',
#   'power',
#   'many',
#   'modern',
#   'weapons',
#   'makes',
#   'cost',
#   'accidental',
#   'crimial',
#   'usage',
#   'these',
#   'weapons',
#   'great',
#   'weapons',
#   'mass',
#   'destruction',
#   'need',
#   'control',
#   'government',
#   'only',
#   'individual',
#   'access',
#   'would',
#   'result',
#   'needless',
#   'deaths',
#   'millions',
#   'this',
#   'makes',
#   'right',
#   'people',
#   'keep',
#   'bear',
#   'many',
#   'modern',
#   'weapons',
#   'existant',
#   'thanks',
#   'stating',
#   'where',
#   'coming',
#   'from',
#   'needless',
#   'disagree',
#   'every',
#   'count',
#   'believe',
#   'that',
#   'individuals',
#   'should',
#   'have',
#   'right',
#   'weapons',
#   'mass',
#   'destruction',
#   'find',
#   'hard',
#   'believe',
#   'that',
#   'would',
#   'support',
#   'neighbor',
#   'right',
#   'keep',
#   'nuclear',
#   'weapons',
#   'biological',
#   'weapons',
#   'nerve',
#   'property',
#   'cannot',
#   'even',
#   'agree',
#   'keeping',
#   'weapons',
#   'mass',
#   'destruction',
#   'hands',
#   'individuals',
#   'there',
#   'hope',
#   'sign',
#   'blank',
#   'checks',
#   'course',
#   'term',
#   'must',
#   'rigidly',
#   'defined',
#   'bill',
#   'when',
#   'doug',
#   'foxvog',
#   'says',
#   'weapons',
#   'mass',
#   'destruction',
#   'means',
#   'nukes',
#   'when',
#   'sarah',
#   'brady',
#   'says',
#   'weapons',
#   'mass',
#   'destruction',
#   'means',
#   'street',
#   'sweeper',
#   'shotguns',
#   'semi',
#   'automatic',
#   'rifles',
#   'doubt',
#   'uses',
#   'this',
#   'term',
#   'that',
#   'using',
#   'quote',
#   'allegedly',
#   'from',
#   'back',
#   'when',
#   'john',
#   'lawrence',
#   'rutledge',
#   'says',
#   'weapons',
#   'mass',
#   'destruction',
#   'then',
#   'immediately',
#   'follows',
#   'with',
#   'thousands',
#   'people',
#   'killed',
#   'each',
#   'year',
#   'handguns',
#   'this',
#   'number',
#   'easily',
#   'reduced',
#   'putting',
#   'reasonable',
#   'restrictions',
#   'them',
#   'what',
#   'does',
#   'rutledge',
#   'mean',
#   'term',
#   'read',
#   'article',
#   'presenting',
#   'first',
#   'argument',
#   'about',
#   'weapons',
#   'mass',
#   'destruction',
#   'commonly',
#   'understood',
#   'then',
#   'switching',
#   'other',
#   'topics',
#   'first',
#   'point',
#   'evidently',
#   'show',
#   'that',
#   'weapons',
#   'should',
#   'allowed',
#   'then',
#   'later',
#   'analysis',
#   'given',
#   'this',
#   'understanding',
#   'consider',
#   'another',
#   'class',
#   'rocket',
#   'stratus',
#   'believe',
#   'that',
#   'speak',
#   'company',
#   'stratus',
#   'write',
#   'today',
#   'special',
#   'investors',
#   'packet',
#   'doug',
#   'foxvog',
#   'douglas',
#   'foxvog'],
#  ['from',
#   'bmdelane',
#   'quads',
#   'uchicago',
#   'brian',
#   'manning',
#   'delaney',
#   'subject',
#   'brain',
#   'tumor',
#   'treatment',
#   'thanks',
#   'reply',
#   'bmdelane',
#   'midway',
#   'uchicago',
#   'organization',
#   'university',
#   'chicago',
#   'lines',
#   'there',
#   'were',
#   'people',
#   'responded',
#   'request',
#   'info',
#   'treatment',
#   'astrocytomas',
#   'through',
#   'email',
#   'whom',
#   'couldn',
#   'thank',
#   'directly',
#   'because',
#   'mail',
#   'bouncing',
#   'probs',
#   'sean',
#   'debra',
#   'sharon',
#   'thought',
#   'publicly',
#   'thank',
#   'everyone',
#   'thanks',
#   'sure',
#   'glad',
#   'accidentally',
#   'instead',
#   'when',
#   'trying',
#   'delete',
#   'file',
#   'last',
#   'september',
#   'hmmm',
#   'news',
#   'what',
#   'this',
#   'brian'],
#  ['from',
#   'bgrubb',
#   'dante',
#   'nmsu',
#   'grubb',
#   'subject',
#   'scsi',
#   'organization',
#   'mexico',
#   'state',
#   'university',
#   'cruces',
#   'lines',
#   'distribution',
#   'world',
#   'nntp',
#   'posting',
#   'host',
#   'dante',
#   'nmsu',
#   'dxb132',
#   'psuvm',
#   'writes',
#   'article',
#   '1qlbrlinn7rk',
#   'dns1',
#   'nmsu',
#   'bgrubb',
#   'dante',
#   'nmsu',
#   'grubb',
#   'says',
#   'magazine',
#   'april',
#   '1993',
#   'although',
#   'scsi',
#   'twice',
#   'fasst',
#   'esdi',
#   'faster',
#   'than',
#   'support',
#   'devices',
#   'acceptance',
#   'long',
#   'been',
#   'stalled',
#   'incompatability',
#   'problems',
#   'installation',
#   'headaches',
#   'love',
#   'when',
#   'magazine',
#   'writers',
#   'make',
#   'stupid',
#   'statements',
#   'like',
#   'that',
#   'performance',
#   'where',
#   'they',
#   'those',
#   'numbers',
#   'list',
#   'actual',
#   'performance',
#   'ranges',
#   'which',
#   'should',
#   'convince',
#   'anyone',
#   'that',
#   'such',
#   'statement',
#   'absurd',
#   'scsi',
#   'ranges',
#   'from',
#   'scsi',
#   'ranges',
#   'from',
#   '40mb',
#   'ranges',
#   'from',
#   'esdi',
#   'always',
#   '25mb',
#   'although',
#   'there',
#   'some',
#   'standard',
#   'versions',
#   'this',
#   'shows',
#   'that',
#   'know',
#   'much',
#   'about',
#   'scsi',
#   'scsi',
#   'with',
#   'scsi',
#   'controler',
#   'chip',
#   'range',
#   'indeed',
#   'that',
#   'have',
#   'right',
#   'about',
#   'scsi',
#   'scsi',
#   'with',
#   'scsi',
#   'controller',
#   'chip',
#   'with',
#   '10mb',
#   'burst',
#   'note',
#   'increase',
#   'speed',
#   'quadra',
#   'uses',
#   'this',
#   'version',
#   'scsi',
#   'does',
#   'exist',
#   'some',
#   'this',
#   'scsi',
#   'scsi',
#   'mode',
#   'with',
#   '10mb',
#   'burst',
#   'scsi',
#   'wide',
#   'fast',
#   'mode',
#   '12mb',
#   'with',
#   '20mb',
#   'burst',
#   'scsi',
#   'wide',
#   'fast',
#   '20mb',
#   'with',
#   '40mb',
#   'burst',
#   'your',
#   'data',
#   'although',
#   'scsi',
#   'twice',
#   'fast',
#   'esdi',
#   'correct',
#   'with',
#   'scsi',
#   'controller',
#   'chip',
#   'scsi',
#   'reach',
#   '10mb',
#   'which',
#   'indeed',
#   'faster',
#   'than',
#   'these',
#   'scsi',
#   'facts',
#   'have',
#   'been',
#   'posted',
#   'this',
#   'newsgroup',
#   'info',
#   'sheet',
#   'available',
#   'sumex',
#   'stanford',
#   'info',
#   'report',
#   'compare',
#   'version',
#   'should',
#   'still',
#   'there',
#   'part',
#   'this',
#   'problem',
#   'both',
#   'inconsiant',
#   'about',
#   'what',
#   'scsi',
#   'which',
#   'though',
#   'well',
#   'documented',
#   'that',
#   'quadra',
#   'scsi',
#   'chip',
#   'apple',
#   'salesperson',
#   'said',
#   'uses',
#   'fast',
#   'scsi',
#   'chip',
#   '10mb',
#   'burst',
#   'does',
#   'scsi',
#   'maximum',
#   'synchronous',
#   'quadra',
#   'uses',
#   'ansynchronous',
#   'scsi',
#   'which',
#   'slower',
#   'seems',
#   'that',
#   'scsi',
#   'interface',
#   'think',
#   'scsi',
#   'when',
#   'maybe',
#   'scsi',
#   'interface',
#   'driven',
#   'machine',
#   'scsi',
#   'controller',
#   'chip',
#   'mode',
#   'which',
#   'much',
#   'faster',
#   'then',
#   'true',
#   'scsi',
#   'slam',
#   'article',
#   'because',
#   'understand',
#   'what',
#   'going',
#   'reference',
#   'quadra',
#   'scsi',
#   'controller',
#   'chip',
#   'digital',
#   'review',
#   '1991'],
#  ['from',
#   'holmes7000',
#   'iscsvax',
#   'subject',
#   'icon',
#   'help',
#   'please',
#   'organization',
#   'university',
#   'northern',
#   'iowa',
#   'lines',
#   'have',
#   'downloaded',
#   'several',
#   'icons',
#   'figure',
#   'change',
#   'wallpaper',
#   'icons',
#   'help',
#   'would',
#   'appreciated',
#   'thanx',
#   'brando',
#   'please',
#   'mail'],
#  ['from',
#   'kerr',
#   'uiuc',
#   'stan',
#   'kerr',
#   'subject',
#   'sigma',
#   'designs',
#   'double',
#   'article',
#   'c52u8x',
#   'organization',
#   'university',
#   'illinois',
#   'urbana',
#   'lines',
#   'jap10',
#   'cwru',
#   'joseph',
#   'pellettiere',
#   'writes',
#   'looking',
#   'information',
#   'about',
#   'sigma',
#   'designs',
#   'double',
#   'board',
#   'figure',
#   'that',
#   'hardware',
#   'compression',
#   'board',
#   'that',
#   'works',
#   'with',
#   'autodoubler',
#   'sure',
#   'about',
#   'this',
#   'also',
#   'much',
#   'would',
#   'cost',
#   'board',
#   'over',
#   'year',
#   'does',
#   'work',
#   'with',
#   'diskdoubler',
#   'with',
#   'autodoubler',
#   'licensing',
#   'problem',
#   'with',
#   'stac',
#   'technologies',
#   'owners',
#   'board',
#   'compression',
#   'technology',
#   'writing',
#   'this',
#   'from',
#   'memory',
#   'lost',
#   'reference',
#   'please',
#   'correct',
#   'wrong',
#   'using',
#   'board',
#   'problems',
#   'with',
#   'file',
#   'icons',
#   'being',
#   'lost',
#   'hard',
#   'whether',
#   'board',
#   'fault',
#   'something',
#   'else',
#   'however',
#   'decompress',
#   'troubled',
#   'file',
#   'recompress',
#   'without',
#   'board',
#   'icon',
#   'usually',
#   'reappears',
#   'because',
#   'above',
#   'mentioned',
#   'licensing',
#   'problem',
#   'freeware',
#   'expansion',
#   'utility',
#   'expand',
#   'will',
#   'decompress',
#   'board',
#   'compressed',
#   'file',
#   'unless',
#   'have',
#   'board',
#   'installed',
#   'since',
#   'stac',
#   'product',
#   'seems',
#   'unlikely',
#   'that',
#   'holes',
#   'autodoubler',
#   'diskdoubler',
#   'related',
#   'board',
#   'will',
#   'fixed',
#   'which',
#   'makes',
#   'very',
#   'reluctant',
#   'stac',
#   'product',
#   'since',
#   'they',
#   'being',
#   'stinky',
#   'that',
#   'competition',
#   'stan',
#   'kerr',
#   'computing',
#   'communications',
#   'services',
#   'office',
#   'illinois',
#   'urbana',
#   'phone',
#   '5217',
#   'email',
#   'stankerr',
#   'uiuc'],
#  ['from',
#   'irwin',
#   'cmptrc',
#   'lonestar',
#   'irwin',
#   'arnstein',
#   'subject',
#   'recommendation',
#   'summary',
#   'what',
#   'worth',
#   'distribution',
#   'expires',
#   '1993',
#   'organization',
#   'computrac',
#   'richardson',
#   'keywords',
#   'ducati',
#   'much',
#   'lines',
#   'have',
#   'line',
#   'ducati',
#   '900gts',
#   '1978',
#   'model',
#   'with',
#   'clock',
#   'runs',
#   'very',
#   'well',
#   'paint',
#   'bronze',
#   'brown',
#   'orange',
#   'faded',
#   'leaks',
#   'pops',
#   'with',
#   'hard',
#   'accel',
#   'shop',
#   'will',
#   'trans',
#   'leak',
#   'they',
#   'sold',
#   'bike',
#   'only',
#   'owner',
#   'they',
#   'want',
#   '3495',
#   'thinking',
#   'more',
#   'like',
#   'opinions',
#   'there',
#   'please',
#   'email',
#   'thanks',
#   'would',
#   'nice',
#   'stable',
#   'mate',
#   'beemer',
#   'then',
#   'bike',
#   'call',
#   'myself',
#   'axis',
#   'motors',
#   'tuba',
#   'irwin',
#   'honk',
#   'therefore',
#   'computrac',
#   'richardson',
#   'irwin',
#   'cmptrc',
#   'lonestar',
#   '0826'],
#  ['from',
#   'david',
#   'terminus',
#   'ericsson',
#   'david',
#   'bold',
#   'subject',
#   'question',
#   'those',
#   'with',
#   'popular',
#   'morality',
#   'reply',
#   'david',
#   'terminus',
#   'ericsson',
#   'distribution',
#   'world',
#   'organization',
#   'camtec',
#   'electronics',
#   'ericsson',
#   'leicester',
#   'england',
#   'lines',
#   'nntp',
#   'posting',
#   'host',
#   'bangkok',
#   'article',
#   '17570',
#   'freenet',
#   'carleton',
#   'ad354',
#   'freenet',
#   'carleton',
#   'james',
#   'owens',
#   'writes',
#   'previous',
#   'article',
#   'david',
#   'terminus',
#   'ericsson',
#   'david',
#   'bold',
#   'says',
#   'mean',
#   'rude',
#   'think',
#   'that',
#   'hold',
#   'wrong',
#   'different',
#   'stick',
#   'david',
#   'look',
#   'your',
#   'posting',
#   'again',
#   'what',
#   'mean',
#   'intent',
#   'explaining',
#   'jung',
#   'thought',
#   'could',
#   'more',
#   'moral',
#   'than',
#   'that',
#   'overlooked',
#   'your',
#   'main',
#   'line',
#   'thought',
#   'seem',
#   'saying',
#   'that',
#   'being',
#   'unknowable',
#   'morality',
#   'unknowable',
#   'that',
#   'pretty',
#   'much',
#   'understand',
#   'that',
#   'this',
#   'jewish',
#   'thinking',
#   'however',
#   'jews',
#   'believe',
#   'that',
#   'covenant',
#   'between',
#   'yhwh',
#   'patriarchs',
#   'abraham',
#   'moses',
#   'this',
#   'case',
#   'establishes',
#   'moral',
#   'code',
#   'follow',
#   'mankind',
#   'even',
#   'jews',
#   'could',
#   'decide',
#   'where',
#   'boundaries',
#   'fall',
#   'though',
#   'understand',
#   'sadducees',
#   'believed',
#   'that',
#   'torah',
#   'that',
#   'required',
#   'whereas',
#   'pharisees',
#   'ancestors',
#   'modern',
#   'judaism',
#   'believed',
#   'that',
#   'torah',
#   'available',
#   'interpretation',
#   'lead',
#   'understanding',
#   'required',
#   'morality',
#   'nuances',
#   'talmud',
#   'essence',
#   'this',
#   'that',
#   'biblical',
#   'morality',
#   'interface',
#   'between',
#   'yhwh',
#   'christian',
#   'does',
#   'necessarily',
#   'indicate',
#   'anything',
#   'about',
#   'yhwh',
#   'outside',
#   'that',
#   'relationship',
#   'although',
#   'speculate',
#   'first',
#   'thing',
#   'that',
#   'comes',
#   'mind',
#   'that',
#   'supposed',
#   'created',
#   'image',
#   'there',
#   'argument',
#   'that',
#   'committed',
#   'whatever',
#   'moral',
#   'code',
#   'follows',
#   'part',
#   'trying',
#   'live',
#   'that',
#   'image',
#   'supposed',
#   'live',
#   'christ',
#   'example',
#   'would',
#   'hard',
#   'pressed',
#   'argue',
#   'that',
#   'what',
#   'what',
#   'kind',
#   'trouble',
#   'with',
#   'this',
#   'that',
#   'really',
#   'know',
#   'what',
#   'created',
#   'image',
#   'means',
#   'heard',
#   'number',
#   'different',
#   'opinions',
#   'this',
#   'have',
#   'still',
#   'come',
#   'conclusion',
#   'this',
#   'rather',
#   'upsets',
#   'apple',
#   'cart',
#   'wants',
#   'base',
#   'life',
#   'script',
#   'this',
#   'shaky',
#   'foundation',
#   'metaphors',
#   'unashamedly',
#   'living',
#   'christ',
#   'example',
#   'know',
#   'very',
#   'little',
#   'about',
#   'jesus',
#   'person',
#   'only',
#   'have',
#   'recorded',
#   'utterances',
#   'narratives',
#   'followers',
#   'some',
#   'very',
#   'small',
#   'references',
#   'from',
#   'comtemporary',
#   'historians',
#   'revelation',
#   'aside',
#   'only',
#   'know',
#   'christ',
#   'second',
#   'hand',
#   'worse',
#   'this',
#   'attempt',
#   'debunk',
#   'christianity',
#   'although',
#   'seem',
#   'that',
#   'initially',
#   'point',
#   'trying',
#   'make',
#   'that',
#   'only',
#   'really',
#   'have',
#   'bible',
#   'interpret',
#   'that',
#   'interpretation',
#   'humanity',
#   'guess',
#   'this',
#   'where',
#   'faith',
#   'relevation',
#   'comes',
#   'with',
#   'inherent',
#   'subjectiveness',
#   'metaphysically',
#   'there',
#   'multiple',
#   'moral',
#   'codes',
#   'then',
#   'there',
#   'absolute',
#   'moral',
#   'code',
#   'think',
#   'this',
#   'theologically',
#   'questionable',
#   'there',
#   'absolute',
#   'moral',
#   'code',
#   'there',
#   'undoubtably',
#   'multiple',
#   'moral',
#   'codes',
#   'multiple',
#   'moral',
#   'codes',
#   'founded',
#   'absolute',
#   'moral',
#   'code',
#   'example',
#   'parent',
#   'tell',
#   'child',
#   'never',
#   'swear',
#   'child',
#   'assume',
#   'that',
#   'parent',
#   'never',
#   'swears',
#   'simply',
#   'because',
#   'parent',
#   'told',
#   'child',
#   'that',
#   'wrong',
#   'parent',
#   'swear',
#   'like',
#   'trooper',
#   'where',
#   'there',
#   'children',
#   'wrongness',
#   'here',
#   'child',
#   'disobeys',
#   'parent',
#   'parent',
#   'feel',
#   'that',
#   'inappropriate',
#   'swear',
#   'front',
#   'children',
#   'quite',
#   'happy',
#   'swear',
#   'front',
#   'animals',
#   'analogy',
#   'does',
#   'quite',
#   'hold',
#   'water',
#   'because',
#   'child',
#   'knows',
#   'that',
#   'same',
#   'type',
#   'parent',
#   'parent',
#   'later',
#   'life',
#   'gist',
#   'incidentally',
#   'young',
#   'child',
#   'considers',
#   'directive',
#   'absolute',
#   'until',
#   'gets',
#   'older',
#   'piaget',
#   'learns',
#   'morality',
#   'david',
#   'religion',
#   'where',
#   'fishes',
#   'cried',
#   'they',
#   'swam',
#   'clearness',
#   'through'],
#  ['from',
#   'rodc',
#   'cerkoney',
#   'subject',
#   'g4qxf',
#   'fekvh6',
#   'nntp',
#   'posting',
#   'host',
#   'hpfcmrc',
#   'organization',
#   'hewlett',
#   'packard',
#   'fort',
#   'collins',
#   'newsreader',
#   'version',
#   'lines',
#   'regards',
#   'cerkoney',
#   '______________________________________________',
#   'cerkoney',
#   'email',
#   'hewlett',
#   'packard',
#   'rodc',
#   '3404',
#   'east',
#   'harmony',
#   'hpdesk',
#   'fort',
#   'collins',
#   '80525',
#   'hp4000',
#   '_____________________________________________'],
#  ['from',
#   'dbm0000',
#   'tm0006',
#   'lerc',
#   'nasa',
#   'david',
#   'mckissock',
#   'subject',
#   'space',
#   'station',
#   'redesign',
#   'alternative',
#   'organization',
#   'nasa',
#   'lewis',
#   'research',
#   'center',
#   'cleveland',
#   'ohio',
#   'lines',
#   'distribution',
#   'world',
#   'nntp',
#   'posting',
#   'host',
#   'tm0006',
#   'lerc',
#   'nasa',
#   'news',
#   'software',
#   'vnews',
#   'article',
#   '1993apr23',
#   '184732',
#   '1105',
#   'nasa',
#   'kjenks',
#   'gothamcity',
#   'nasa',
#   'writes',
#   'description',
#   'external',
#   'tank',
#   'option',
#   'redesign',
#   'deleted',
#   'mark',
#   'proposed',
#   'this',
#   'design',
#   'shea',
#   'committee',
#   'crystal',
#   'city',
#   'reports',
#   'that',
#   'warmly',
#   'received',
#   'however',
#   'rumors',
#   'hear',
#   'that',
#   'design',
#   'based',
#   'wingless',
#   'space',
#   'shuttle',
#   'orbiter',
#   'seems',
#   'more',
#   'likely',
#   'keep',
#   'things',
#   'both',
#   'external',
#   'tank',
#   'wingless',
#   'orbiter',
#   'options',
#   'have',
#   'been',
#   'deleted',
#   'from',
#   'redesign',
#   'options',
#   'list',
#   'today',
#   'edition',
#   'york',
#   'times',
#   'reports',
#   'that',
#   'connor',
#   'told',
#   'panel',
#   'that',
#   'some',
#   'redesign',
#   'proposals',
#   'have',
#   'been',
#   'dropped',
#   'such',
#   'using',
#   'giant',
#   'external',
#   'fuel',
#   'tanks',
#   'used',
#   'launching',
#   'space',
#   'shuttles',
#   'building',
#   'station',
#   'around',
#   'existing',
#   'space',
#   'shuttle',
#   'with',
#   'wings',
#   'tail',
#   'removed',
#   'currently',
#   'there',
#   'three',
#   'options',
#   'being',
#   'considered',
#   'presented',
#   'advisory',
#   'panel',
#   'meeting',
#   'yesterday',
#   'reported',
#   'today',
#   'times',
#   'option',
#   'cost',
#   'modular',
#   'approach',
#   'this',
#   'option',
#   'being',
#   'studied',
#   'team',
#   'from',
#   'msfc',
#   'aside',
#   'there',
#   'redesign',
#   'teams',
#   'msfc',
#   'larc',
#   'supporting',
#   'station',
#   'redesign',
#   'team',
#   'crystal',
#   'city',
#   'both',
#   'lerc',
#   'reston',
#   'folks',
#   'also',
#   'site',
#   'these',
#   'locations',
#   'helping',
#   'respective',
#   'teams',
#   'with',
#   'their',
#   'redesign',
#   'activities',
#   'features',
#   'this',
#   'option',
#   'uses',
#   'modular',
#   'developed',
#   'lockheed',
#   'that',
#   'qualified',
#   'provides',
#   'propulsion',
#   'communications',
#   'data',
#   'management',
#   'lockheed',
#   'developed',
#   'this',
#   'force',
#   'power',
#   'station',
#   'capability',
#   'obtained',
#   'shuttle',
#   'flights',
#   'solar',
#   'arrays',
#   'used',
#   'provide',
#   'power',
#   'vehicle',
#   'flies',
#   'arrow',
#   'mode',
#   'optimize',
#   'microgravity',
#   'environment',
#   'shuttle',
#   'spacelab',
#   'missions',
#   'would',
#   'utilize',
#   'vehilce',
#   'power',
#   'source',
#   'missions',
#   'human',
#   'tended',
#   'capability',
#   'opposed',
#   'sexist',
#   'term',
#   'tended',
#   'capability',
#   'achieved',
#   'addition',
#   'common',
#   'module',
#   'this',
#   'modified',
#   'version',
#   'existing',
#   'module',
#   'docking',
#   'ports',
#   'added',
#   'international',
#   'partners',
#   'labs',
#   'taking',
#   'place',
#   'nodes',
#   'shuttle',
#   'docked',
#   'station',
#   'missions',
#   'orbiter',
#   'would',
#   'provide',
#   'crew',
#   'habitability',
#   'capability',
#   'international',
#   'human',
#   'tended',
#   'nasda',
#   'modules',
#   'another',
#   'power',
#   'permanent',
#   'human',
#   'presence',
#   'capability',
#   'power',
#   'module',
#   'habitation',
#   'module',
#   'acrv',
#   'assured',
#   'crew',
#   'return',
#   'vehicle',
#   'option',
#   'space',
#   'station',
#   'freedom',
#   'derived',
#   'option',
#   'team',
#   'based',
#   'larc',
#   'lead',
#   'mike',
#   'griffin',
#   'this',
#   'option',
#   'looks',
#   'alot',
#   'like',
#   'existing',
#   'design',
#   'which',
#   'have',
#   'come',
#   'know',
#   'love',
#   'this',
#   'option',
#   'assumes',
#   'lightweight',
#   'external',
#   'tank',
#   'available',
#   'assembly',
#   'flights',
#   'does',
#   'option',
#   'also',
#   'number',
#   'flights',
#   'computed',
#   'inclination',
#   'orbit',
#   'both',
#   'options',
#   'build',
#   'occurs',
#   'phases',
#   'initial',
#   'research',
#   'capability',
#   'reached',
#   'after',
#   'flights',
#   'power',
#   'transferred',
#   'from',
#   'vehicle',
#   'orbiter',
#   'spacelab',
#   'when',
#   'visits',
#   'tended',
#   'capability',
#   'griffin',
#   'adopted',
#   'sexist',
#   'language',
#   'achieved',
#   'after',
#   'flights',
#   'deployed',
#   'solar',
#   'power',
#   'module',
#   'provides',
#   'power',
#   'permanent',
#   'human',
#   'presence',
#   'capability',
#   'occurs',
#   'after',
#   'flights',
#   'keeping',
#   'orbiter',
#   'orbit',
#   'acrv',
#   'sometimes',
#   'there',
#   'would',
#   'orbiters',
#   'orbit',
#   'acrv',
#   'second',
#   'that',
#   'comes',
#   'logistics',
#   'supply',
#   'fault',
#   'tolerance',
#   'capability',
#   'achieved',
#   'after',
#   'flights',
#   'with',
#   'addition',
#   'power',
#   'module',
#   'another',
#   'thermal',
#   'control',
#   'system',
#   'radiator',
#   'more',
#   'propulsion',
#   'modules',
#   'after',
#   'flights',
#   'internationals',
#   'board',
#   'more',
#   'power',
#   'habitation',
#   'module',
#   'acrv',
#   'added',
#   'finish',
#   'assembly',
#   'flights',
#   'most',
#   'systems',
#   'currently',
#   'used',
#   'this',
#   'option',
#   'with',
#   'exception',
#   'data',
#   'management',
#   'system',
#   'which',
#   'major',
#   'changes',
#   'option',
#   'single',
#   'core',
#   'launch',
#   'station',
#   'this',
#   'lead',
#   'option',
#   'basically',
#   'take',
#   'diameter',
#   'cylinder',
#   'that',
#   'long',
#   'slap',
#   'space',
#   'shuttle',
#   'main',
#   'engines',
#   'backside',
#   'nose',
#   'cone',
#   'attached',
#   'regular',
#   'shuttle',
#   'external',
#   'tank',
#   'regular',
#   'solid',
#   'rocket',
#   'motors',
#   'launch',
#   'some',
#   'features',
#   'complete',
#   'ground',
#   'integration',
#   'checkout',
#   'tangentially',
#   'mounted',
#   'fixed',
#   'solar',
#   'panels',
#   'body',
#   'mounted',
#   'radiators',
#   'which',
#   'adds',
#   'protection',
#   'against',
#   'micrometeroid',
#   'orbital',
#   'debris',
#   'centerline',
#   'docking',
#   'ports',
#   'each',
#   'berthing',
#   'ports',
#   'single',
#   'pressurized',
#   'volume',
#   'approximately',
#   'cubic',
#   'feet',
#   'twice',
#   'volume',
#   'skylab',
#   'floors',
#   'center',
#   'passageway',
#   'between',
#   'floors',
#   'housekeeping',
#   'power',
#   'graceful',
#   'degradation',
#   'with',
#   'failures',
#   'power',
#   'channels',
#   'thermal',
#   'loops',
#   'dual',
#   'environmental',
#   'control',
#   'life',
#   'support',
#   'system',
#   'increased',
#   'crew',
#   'time',
#   'utilization',
#   'micro',
#   'thru',
#   'core',
#   'module'],
#  ['from',
#   'jllee',
#   'acsu',
#   'buffalo',
#   'johnny',
#   'subject',
#   'moving',
#   'sale',
#   'summary',
#   'moving',
#   'sale',
#   'organization',
#   'lines',
#   'nntp',
#   'posting',
#   'host',
#   'lictor',
#   'acsu',
#   'buffalo',
#   'reduced',
#   'prices',
#   'have',
#   'list',
#   'things',
#   'forsale',
#   'behalf',
#   'brother',
#   'moving',
#   'moved',
#   'already',
#   'offer',
#   'black',
#   'decker',
#   'duster',
#   'plus',
#   'portable',
#   'hand',
#   'vaccum',
#   'purchased',
#   '1000',
#   'dual',
#   'cassette',
#   'portable',
#   'player',
#   'band',
#   'graphics',
#   'equalizer',
#   'high',
#   'speed',
#   'dubing',
#   'tape',
#   'tape',
#   'deck',
#   'seems',
#   'have',
#   'lost',
#   'treble',
#   'sound',
#   'fixable',
#   'purchased',
#   'monolux',
#   'zoom',
#   'microscope',
#   '1200x',
#   'magnification',
#   'made',
#   'japan',
#   'includes',
#   'case',
#   'accessories',
#   'purchased',
#   'sunbeam',
#   '1400',
#   'hair',
#   'dryer',
#   'dryer',
#   'your',
#   'head',
#   'under',
#   'into',
#   'know',
#   'ones',
#   'salons',
#   'purchased',
#   'everylast',
#   'speed',
#   'leather',
#   'brand',
#   'never',
#   'used',
#   'osterizer',
#   'pusle',
#   'matic',
#   'blender',
#   'with',
#   'speeds',
#   'cookbook',
#   'years',
#   'purchased',
#   'binolux',
#   'binoculars',
#   '7x35',
#   'extra',
#   'wide',
#   'angle',
#   '525ft',
#   '1000yds',
#   'with',
#   'case',
#   'very',
#   'proctor',
#   'silex',
#   'spray',
#   'steam',
#   'iron',
#   'very',
#   'questions',
#   'contact',
#   'thru',
#   'mail',
#   'will',
#   'reply',
#   'expeditously',
#   'always',
#   'included',
#   'please',
#   'consider',
#   'this',
#   'lastly',
#   'very',
#   'reasonable',
#   'very',
#   'reasonable',
#   'thanks',
#   'john'],
#  ['from',
#   'mathew',
#   'mathew',
#   'mantis',
#   'subject',
#   'political',
#   'atheists',
#   'organization',
#   'mantis',
#   'consultants',
#   'cambridge',
#   'newsreader',
#   'rusnews',
#   'lines',
#   'kmr4',
#   'cwru',
#   'keith',
#   'ryan',
#   'writes',
#   'almost',
#   'sure',
#   'that',
#   'zyklon',
#   'immediate',
#   'painless',
#   'method',
#   'death',
#   'insert',
#   'soem',
#   'other',
#   'form',
#   'ethnic',
#   'minority',
#   'groups',
#   'have',
#   'been',
#   'killed',
#   'mutilated',
#   'exterminated',
#   'through',
#   'history',
#   'guess',
#   'unusual',
#   'would',
#   'agree',
#   'that',
#   'holocost',
#   'would',
#   'allowed',
#   'under',
#   'constitution',
#   'punishment',
#   'doubt',
#   'they',
#   'recieved',
#   'what',
#   'would',
#   'considered',
#   'fair',
#   'trial',
#   'standards',
#   'sure',
#   'look',
#   'what',
#   'happened',
#   'japanese',
#   'citizens',
#   'during',
#   'world',
#   'prepared',
#   'round',
#   'these',
#   'people',
#   'stick',
#   'them',
#   'concentration',
#   'camp',
#   'without',
#   'trial',
#   'only',
#   'short',
#   'step',
#   'gassing',
#   'them',
#   'without',
#   'trial',
#   'after',
#   'seems',
#   'that',
#   'nazis',
#   'originally',
#   'only',
#   'intended',
#   'imprison',
#   'jews',
#   'final',
#   'solution',
#   'dreamt',
#   'partly',
#   'because',
#   'they',
#   'couldn',
#   'afford',
#   'camps',
#   'because',
#   'devastation',
#   'caused',
#   'goering',
#   'total',
#   'those',
#   'weren',
#   'gassed',
#   'generally',
#   'died',
#   'malnutrition',
#   'disease',
#   'mathew'],
#  ['from',
#   'nova',
#   'purdue',
#   'allen',
#   'subject',
#   'tiff',
#   'philosophical',
#   'significance',
#   'organization',
#   'purdue',
#   'university',
#   'lines',
#   'article',
#   'prestonm',
#   '735400848',
#   'prestonm',
#   'martin',
#   'preston',
#   'writes',
#   'library',
#   'reading',
#   'writing',
#   'tiff',
#   'files',
#   'took',
#   'good',
#   'minutes',
#   'start',
#   'using',
#   'them',
#   'your',
#   'certainly',
#   'whenever',
#   'have',
#   'tiff',
#   'usually',
#   'works',
#   'very',
#   'well',
#   'that',
#   'point',
#   'philosophically',
#   'opposed',
#   'because',
#   'complexity',
#   'this',
#   'complexity',
#   'some',
#   'programs',
#   'poor',
#   'tiff',
#   'writers',
#   'making',
#   'some',
#   'very',
#   'bizarre',
#   'files',
#   'other',
#   'programs',
#   'inability',
#   'load',
#   'tiff',
#   'images',
#   'though',
#   'they',
#   'save',
#   'them',
#   'course',
#   'general',
#   'inability',
#   'interchange',
#   'images',
#   'between',
#   'different',
#   'environments',
#   'despite',
#   'fact',
#   'they',
#   'think',
#   'they',
#   'understand',
#   'tiff',
#   'saying',
#   'goes',
#   'worried',
#   'about',
#   'other',
#   'assholes',
#   'there',
#   'trouble',
#   'with',
#   'misuse',
#   'abuse',
#   'tiff',
#   'over',
#   'years',
#   'chalk',
#   'immense',
#   'unnecessary',
#   'complexity',
#   'format',
#   'words',
#   'tiff',
#   'spec',
#   'appendix',
#   'page',
#   'capitalized',
#   'emphasis',
#   'mine',
#   'only',
#   'problem',
#   'with',
#   'this',
#   'sort',
#   'success',
#   'that',
#   'tiff',
#   'designed',
#   'powerful',
#   'flexible',
#   'expense',
#   'simplicity',
#   'takes',
#   'fair',
#   'amount',
#   'effort',
#   'handle',
#   'options',
#   'currently',
#   'defined',
#   'this',
#   'specification',
#   'probably',
#   'application',
#   'does',
#   'complete',
#   'that',
#   'currently',
#   'only',
#   'sure',
#   'that',
#   'will',
#   'able',
#   'import',
#   'tiff',
#   'image',
#   'since',
#   'there',
#   'many',
#   'image',
#   'generating',
#   'applications',
#   'there',
#   'program',
#   'worse',
#   'applications',
#   'read',
#   'every',
#   'tiff',
#   'image',
#   'that',
#   'means',
#   'there',
#   'some',
#   'some',
#   'that',
#   'might',
#   'have',
#   'deal',
#   'with',
#   'would',
#   'want',
#   'images',
#   'trapped',
#   'that',
#   'format',
#   'neither',
#   'should',
#   'anyone',
#   'agrees',
#   'with',
#   'reasoning',
#   'that',
#   'anyone',
#   'does',
#   'course'],
#  ['from',
#   'cpkjp',
#   'latech',
#   'kevin',
#   'parker',
#   'subject',
#   'insurance',
#   'rates',
#   'performance',
#   'cars',
#   'summary',
#   'organization',
#   'louisiana',
#   'tech',
#   'university',
#   'lines',
#   'nntp',
#   'posting',
#   'host',
#   'latech',
#   'newsreader',
#   'recently',
#   'posted',
#   'article',
#   'asking',
#   'what',
#   'kind',
#   'rates',
#   'single',
#   'male',
#   'drivers',
#   'under',
#   'were',
#   'paying',
#   'performance',
#   'cars',
#   'here',
#   'summary',
#   'replies',
#   'received',
#   'under',
#   'anymore',
#   'close',
#   'enough',
#   '1992',
#   'dodge',
#   'stealth',
#   'twin',
#   'turbo',
#   '300hp',
#   'model',
#   'tickets',
#   'accidents',
#   'house',
#   'have',
#   'taken',
#   'defensive',
#   'driving',
#   'airbag',
#   'security',
#   'alarm',
#   'single',
#   '1500',
#   'year',
#   'decut',
#   'state',
#   'farm',
#   'insurance',
#   'this',
#   'includes',
#   'additional',
#   'umbrella',
#   'policy',
#   'over',
#   'house',
#   'base',
#   'policy',
#   'standard',
#   'policy',
#   'required',
#   'after',
#   'defensive',
#   'driving',
#   'course',
#   'will',
#   'less',
#   'bought',
#   'september',
#   '1992',
#   'company',
#   'with',
#   'never',
#   'accident',
#   'ticket',
#   'years',
#   'quoted',
#   'hope',
#   'this',
#   'helps',
#   'steve',
#   'flynn',
#   'university',
#   'delaware',
#   'kevin',
#   'hope',
#   'remembered',
#   'your',
#   'name',
#   'correctly',
#   'asked',
#   'about',
#   'insurance',
#   'performance',
#   'cars',
#   'well',
#   'last',
#   'year',
#   'similar',
#   'situation',
#   'before',
#   'bought',
#   'made',
#   'same',
#   'inquiry',
#   'then',
#   '1992',
#   'eagle',
#   'talon',
#   'driving',
#   'record',
#   'clean',
#   'state',
#   'illinois',
#   'cost',
#   'turn',
#   'insurance',
#   'goes',
#   'down',
#   'also',
#   'single',
#   'that',
#   'incurs',
#   'higher',
#   'rate',
#   'with',
#   'company',
#   'couple',
#   'other',
#   'friends',
#   'awds',
#   'they',
#   'more',
#   'than',
#   'different',
#   'companies',
#   'also',
#   'maybe',
#   'just',
#   'lucky',
#   'hope',
#   'info',
#   'helps',
#   'dans',
#   'motorola',
#   'cellular',
#   'subscriber',
#   'group',
#   'live',
#   'norman',
#   'oklahoma',
#   'drive',
#   'thunderbird',
#   'have',
#   'never',
#   'made',
#   'claim',
#   'against',
#   'insurance',
#   'though',
#   'have',
#   'been',
#   'several',
#   'times',
#   'negligent',
#   'drivers',
#   'couldn',
#   'stop',
#   'signs',
#   'were',
#   'fiddling',
#   'with',
#   'their',
#   'radios',
#   'have',
#   'three',
#   'moving',
#   'violations',
#   'last',
#   'months',
#   'going',
#   'failure',
#   'clear',
#   'intersection',
#   'still',
#   'damn',
#   'light',
#   'yellow',
#   'going',
#   'which',
#   'didn',
#   'record',
#   'rates',
#   'from',
#   'state',
#   'farm',
#   'with',
#   'passive',
#   'restraint',
#   'deduction',
#   'liability',
#   'deductible',
#   'comprehensive',
#   'deductible',
#   'collision',
#   'roughly',
#   '1300',
#   'year',
#   'paying',
#   'just',
#   'over',
#   '1100',
#   'year',
#   'escort',
#   'james',
#   'james',
#   'callison',
#   'microcomputer',
#   'coordinator',
#   'oklahoma',
#   'center',
#   'callison',
#   'uokmax',
#   'uoknor',
#   'callison',
#   'aardvark',
#   'uoknor',
#   'disclaimer',
#   'engineer',
#   'play',
#   'work',
#   'forecast',
#   'calls',
#   'thunder',
#   'bird',
#   'hell',
#   'thing',
#   'killing',
#   'take',
#   'away',
#   'ever',
#   'gonna',
#   'have',
#   'will',
#   'munny',
#   'unforgiven',
#   'beyond',
#   'under',
#   'group',
#   'have',
#   'experience',
#   'years',
#   'that',
#   'might',
#   'interesting',
#   'owned',
#   '1985',
#   'toyota',
#   'celica',
#   'decided',
#   'myself',
#   'gift',
#   'more',
#   'exotic',
#   'front',
#   'runners',
#   'included',
#   'toyota',
#   'supra',
#   'turbo',
#   'porsche',
#   '1987',
#   'model',
#   'years',
#   'narrowed',
#   'down',
#   'those',
#   'liked',
#   'simplicity',
#   'handling',
#   'snob',
#   'appeal',
#   'driving',
#   'porsche',
#   'supra',
#   'turbo',
#   'less',
#   'money',
#   'more',
#   'features',
#   'performance',
#   'almost',
#   'personal',
#   'luxury',
#   'better',
#   'acceleration',
#   'higher',
#   'speed',
#   'than',
#   'almost',
#   'ready',
#   'give',
#   'buying',
#   'impulse',
#   'decided',
#   'stop',
#   'insurance',
#   'agent',
#   'office',
#   'asked',
#   'about',
#   'what',
#   'would',
#   'happen',
#   'rate',
#   'with',
#   'either',
#   'supra',
#   'your',
#   'rate',
#   'classification',
#   'will',
#   'same',
#   'celica',
#   'celica',
#   'considered',
#   'subcompact',
#   'that',
#   'year',
#   'rated',
#   'safest',
#   'cars',
#   'with',
#   'slight',
#   'increase',
#   'because',
#   'will',
#   'years',
#   'newer',
#   'lower',
#   'risk',
#   'division',
#   'will',
#   'continue',
#   'handle',
#   'your',
#   'account',
#   'porsche',
#   'have',
#   'change',
#   'standard',
#   'higher',
#   'rate',
#   'company',
#   'your',
#   'rate',
#   'will',
#   'double',
#   'with',
#   'another',
#   'story',
#   'again',
#   'cover',
#   'rest',
#   'this',
#   'year',
#   'cancel',
#   'after',
#   'that',
#   'supra',
#   'much',
#   'faster',
#   'than',
#   'actually',
#   'faster',
#   'than',
#   'standard',
#   'that',
#   'doens',
#   'make',
#   'sense',
#   'that',
#   'what',
#   'book',
#   'says',
#   'insure',
#   'corvettes',
#   'either',
#   'some',
#   'reason',
#   'underwriters',
#   'consider',
#   'supras',
#   'their',
#   'drivers',
#   'very',
#   'traditional',
#   'conservative',
#   'eventually',
#   'went',
#   'with',
#   'supra',
#   'number',
#   'reasons',
#   'porsche',
#   'dealer',
#   'nice',
#   'salesman',
#   'interested',
#   'tough',
#   'high',
#   'pressure',
#   'back',
#   'room',
#   'equal',
#   'monthly',
#   'payments',
#   'would',
#   'have',
#   'taken',
#   'year',
#   'longer',
#   'porsche',
#   'plus',
#   'higher',
#   'insurance',
#   'concluded',
#   'that',
#   'high',
#   'insurance',
#   'related',
#   'probability',
#   'auto',
#   'theft',
#   'everyone',
#   'entitled',
#   'opinion',
#   'goldberg',
#   'oasys',
#   'navy',
#   'imagination',
#   'more',
#   'important',
#   'than',
#   'knowledge',
#   'albert',
#   'einstein',
#   'live',
#   'idaho',
#   'when',
#   'many',
#   'years',
#   'years',
#   'bought',
#   'trans',
#   'insurance',
#   'about',
#   '1300',
#   'year',
#   'when',
#   'turned',
#   'immediately',
#   'dropped',
#   'year',
#   'accidents',
#   'before',
#   'after',
#   'this',
#   'strictly',
#   'change',
#   'that',
#   'same',
#   'rate',
#   'stayed',
#   'pretty',
#   'much',
#   'same',
#   'until',
#   'sold',
#   'years',
#   'pickup',
#   'about',
#   'year',
#   'less',
#   'real',
#   'amazing',
#   'thing',
#   'that',
#   'when',
#   'woke',
#   'felt',
#   'much',
#   'more',
#   'responsible',
#   'than',
#   'before',
#   'your',
#   'information',
#   'california',
#   'male',
#   'single',
#   'under',
#   'moving',
#   'violation',
#   'alfa',
#   'spider',
#   '2000',
#   'year',
#   'what',
#   'bargain',
#   'single',
#   'male',
#   'clean',
#   'driving',
#   'record',
#   'have',
#   'corrado',
#   'live',
#   'jose',
#   'california',
#   '1500',
#   'year',
#   'through',
#   'allstate',
#   'good',
#   'deal',
#   'thinking',
#   'about',
#   'getting',
#   'talon',
#   'think',
#   'insurance',
#   'higher',
#   'turbo',
#   'sports',
#   '1986',
#   'honda',
#   'clean',
#   'record',
#   'small',
#   'mexico',
#   'town',
#   'around',
#   'year',
#   'nearby',
#   'city',
#   'rates',
#   'were',
#   'higher',
#   'than',
#   'where',
#   'mine',
#   'insured',
#   'robert',
#   'robert',
#   'stack',
#   'institute',
#   'transportation',
#   'studies',
#   'univ',
#   'california',
#   'irvine',
#   'stack',
#   'translab',
#   'mazda',
#   'protege',
#   '1300',
#   'year',
#   '1992',
#   'saturn',
#   'years',
#   'state',
#   'mexico',
#   'insurance',
#   'state',
#   'farm',
#   'here',
#   'info',
#   'toyota',
#   'celica',
#   'insurance',
#   'farmer',
#   'insurance',
#   'yearly',
#   'insurance',
#   '2028',
#   'date',
#   'license',
#   '1992',
#   'residence',
#   'mountain',
#   'view',
#   'california',
#   'moving',
#   'violations',
#   'atleast',
#   'hope',
#   'this',
#   'helps',
#   'please',
#   'post',
#   'summary',
#   'possible',
#   'vijay',
#   'vijay',
#   'anisetti',
#   'email',
#   'anisetti',
#   'informix',
#   '0320',
#   '6547',
#   'single',
#   'years',
#   'eagle',
#   'talon',
#   'turbo',
#   '1200',
#   'full',
#   'cover',
#   'reasonable',
#   'liability',
#   'tickets',
#   'violations',
#   'accidents',
#   'knock',
#   'wood',
#   'mass',
#   'thing',
#   'that',
#   'makes',
#   'huge',
#   'difference',
#   'mass',
#   'town',
#   'live',
#   'personally',
#   'best',
#   'towns',
#   'within',
#   'reasonable',
#   'distance',
#   'boston',
#   'moved',
#   'absolute',
#   'best',
#   'would',
#   'down',
#   'about',
#   '1150',
#   'moved',
#   'worst',
#   'would',
#   '2000',
#   'also',
#   'accident',
#   'couple',
#   'tickets',
#   'would',
#   'probably',
#   'another',
#   'have',
#   '1990',
#   'mitsubishi',
#   'eclipse',
#   'turbo',
#   'years',
#   'have',
#   'tickets',
#   'that',
#   'went',
#   'record',
#   'live',
#   'illinois',
#   'just',
#   'outside',
#   'chicago',
#   '1560',
#   'year',
#   'with',
#   'full',
#   'coverage',
#   'state',
#   'farm',
#   'small',
#   'discount',
#   'because',
#   'alarm',
#   'system',
#   'year',
#   'only',
#   'live',
#   'miles',
#   'from',
#   'chicago',
#   'actually',
#   'lived',
#   'city',
#   'price',
#   'would',
#   'about',
#   '2000',
#   'year',
#   'over',
#   'case',
#   'interested',
#   'anyway',
#   'insuring',
#   'month',
#   'thats',
#   '100k',
#   'personal',
#   '300k',
#   'total',
#   '100k',
#   'property',
#   'with',
#   'deductible',
#   'glass',
#   'towing',
#   'state',
#   'farm',
#   'unless',
#   'under',
#   'have',
#   'been',
#   'driving',
#   'less',
#   'than',
#   'years',
#   'think',
#   'being',
#   'seriously',
#   'ripped',
#   'have',
#   'performance',
#   'cars',
#   'listed',
#   'your',
#   'record',
#   'clean',
#   'then',
#   'should',
#   'paying',
#   'over',
#   'calling',
#   'insurance',
#   'dealers',
#   'could',
#   'find',
#   'although',
#   'rates',
#   'supposed',
#   'standardized',
#   'found',
#   'that',
#   'most',
#   'places',
#   'initially',
#   'call',
#   'give',
#   'some',
#   'ridiculously',
#   'high',
#   'quote',
#   'finaly',
#   'that',
#   'much',
#   'lower',
#   'also',
#   'have',
#   'changed',
#   'insurance',
#   'companies',
#   'when',
#   'rate',
#   'went',
#   'renewal',
#   'accidents',
#   'tickets',
#   'gets',
#   'older',
#   'maintain',
#   'rate',
#   'always',
#   'have',
#   'careful',
#   'when',
#   'comes',
#   'insurance',
#   'companies',
#   'good',
#   'luck',
#   'serge'],
#  ['from',
#   'ritley',
#   'uimrl7',
#   'uiuc',
#   'subject',
#   'seeking',
#   'thermocouple',
#   'amplifier',
#   'circuit',
#   'reply',
#   'ritley',
#   'uiucmrl',
#   'bitnet',
#   'organization',
#   'materials',
#   'research',
#   'lines',
#   'would',
#   'like',
#   'able',
#   'amplify',
#   'voltage',
#   'signal',
#   'which',
#   'output',
#   'from',
#   'thermocouple',
#   'preferably',
#   'factor',
#   '1000',
#   'that',
#   'resulting',
#   'voltage',
#   'more',
#   'easily',
#   'into',
#   'personal',
#   'computer',
#   'based',
#   'data',
#   'acquisition',
#   'card',
#   'might',
#   'anyone',
#   'able',
#   'point',
#   'references',
#   'such',
#   'circuits',
#   'have',
#   'seen',
#   'simple',
#   'amplifier',
#   'circuits',
#   'before',
#   'sure',
#   'well',
#   'they',
#   'work',
#   'practice',
#   'this',
#   'case',
#   'like',
#   'something',
#   'which',
#   'will',
#   'amplify',
#   'sufficiently',
#   'nicely',
#   'used',
#   'thermocouples',
#   'degrees',
#   'accuracy',
#   'better',
#   'pointers',
#   'would',
#   'greatly',
#   'appreciated'],
#  ['from',
#   'abarden',
#   'tybse1',
#   'uucp',
#   'marie',
#   'barden',
#   'subject',
#   'terminal',
#   'config',
#   'file',
#   'question',
#   'organization',
#   'tybrin',
#   'corporation',
#   'shalimar',
#   'distribution',
#   'lines',
#   'question',
#   'what',
#   'exact',
#   'entry',
#   'parameter',
#   'syntax',
#   'please',
#   'terminal',
#   'configuration',
#   'file',
#   'loaded',
#   'when',
#   'terminal',
#   'boots',
#   'another',
#   'system',
#   'access',
#   'control',
#   'list',
#   'background',
#   'have',
#   'unix',
#   'systems',
#   'running',
#   'x11r3',
#   'x11r4',
#   'ss10',
#   'without',
#   'want',
#   'have',
#   'window',
#   'terminal',
#   'same',
#   'time',
#   'this',
#   'manually',
#   'network',
#   'parameter',
#   'access',
#   'control',
#   'list',
#   'then',
#   'login',
#   'telnet',
#   'session',
#   'great',
#   'tried',
#   'xhost',
#   'work',
#   'failed',
#   'either',
#   'syntax',
#   'wrong',
#   'x11r3',
#   'implementation',
#   'bogus',
#   'trying',
#   'edit',
#   'configuration',
#   'file',
#   'that',
#   'loaded',
#   'when',
#   'boots',
#   'matter',
#   'what',
#   'entry',
#   'edit',
#   'still',
#   'boots',
#   'with',
#   'access',
#   'control',
#   'list',
#   'containing',
#   'only',
#   'manuals',
#   'worthless',
#   'help',
#   'would',
#   'most',
#   'appreciated',
#   'thanks',
#   'marie',
#   'barden',
#   'abarden',
#   'afseo',
#   'eglin'],
#  ['from',
#   'keith',
#   'caltech',
#   'keith',
#   'allan',
#   'schneider',
#   'subject',
#   'pompous',
#   'organization',
#   'california',
#   'institute',
#   'technology',
#   'pasadena',
#   'lines',
#   'nntp',
#   'posting',
#   'host',
#   'punisher',
#   'caltech',
#   'livesey',
#   'solntze',
#   'livesey',
#   'writes',
#   'little',
#   'things',
#   'above',
#   'were',
#   'reference',
#   'germany',
#   'clearly',
#   'people',
#   'said',
#   'that',
#   'there',
#   'were',
#   'similar',
#   'things',
#   'germany',
#   'could',
#   'name',
#   'that',
#   'true',
#   'gave',
#   'examples',
#   'rather',
#   'pevasive',
#   'anti',
#   'semitism',
#   'german',
#   'christianity',
#   'well',
#   'before',
#   'hitler',
#   'arrived',
#   'other',
#   'system',
#   'social',
#   'ranks',
#   'that',
#   'were',
#   'used',
#   'imperail',
#   'germany',
#   'austria',
#   'distinguish',
#   'jews',
#   'from',
#   'rest',
#   'population',
#   'these',
#   'seem',
#   'like',
#   'little',
#   'things',
#   'least',
#   'they',
#   'orders',
#   'worse',
#   'than',
#   'motto',
#   'think',
#   'that',
#   'motto',
#   'little',
#   'thing',
#   'that',
#   'will',
#   'lead',
#   'worse',
#   'things',
#   'keith'],
#  ['from',
#   'leunggm',
#   'odin',
#   'control',
#   'utoronto',
#   'gary',
#   'leung',
#   'subject',
#   'team',
#   'captains',
#   'organization',
#   'university',
#   'toronto',
#   'systems',
#   'control',
#   'group',
#   'lines',
#   'article',
#   '1993apr20',
#   '151818',
#   '4319',
#   'samba',
#   'scott',
#   'marks',
#   'launchpad',
#   'scott',
#   'marks',
#   'writes',
#   'course',
#   'mike',
#   'ramsey',
#   'time',
#   'captain',
#   'buffalo',
#   'prior',
#   'being',
#   'traded',
#   'pittsburgh',
#   'currently',
#   'penguins',
#   'have',
#   'former',
#   'captains',
#   'real',
#   'captain',
#   'lemieux',
#   'playing',
#   'them',
#   'they',
#   'rotate',
#   'during',
#   'season',
#   'even',
#   'while',
#   'mario',
#   'even',
#   'troy',
#   'loney',
#   'worn',
#   'pens',
#   'think',
#   'that',
#   'mike',
#   'foligno',
#   'captain',
#   'sabres',
#   'when',
#   'traded',
#   'leafs',
#   'also',
#   'wasn',
#   'rick',
#   'vaive',
#   'captain',
#   'leafs',
#   'when',
#   'traded',
#   'chicago',
#   'with',
#   'steve',
#   'thomas',
#   'olcyzk',
#   'someone',
#   'speaking',
#   'leafs',
#   'believe',
#   'that',
#   'darryl',
#   'sittler',
#   'their',
#   'captain',
#   'torn',
#   'jersey',
#   'think',
#   'claimed',
#   'captaincy',
#   'later',
#   'when',
#   'traded',
#   'flyers',
#   'yeah',
#   'course',
#   'gretzky',
#   'captain',
#   'oilers',
#   'before',
#   'traded',
#   'wasn',
#   'gary'],
#  ['from',
#   'rpwhite',
#   'navy',
#   'rpwhite',
#   'subject',
#   'catalog',
#   'hard',
#   'find',
#   'enhancements',
#   'repost',
#   'organization',
#   'naval',
#   'postgraduate',
#   'school',
#   'monterey',
#   'distribution',
#   'lines',
#   'andy',
#   'freeman',
#   'writes',
#   'doll',
#   'writes',
#   'catalog',
#   'personal',
#   'computing',
#   'tools',
#   'engineers',
#   'scien',
#   'tists',
#   'lists',
#   'hardware',
#   'cards',
#   'application',
#   'software',
#   'packages',
# ...
#   'stock',
#   'need',
#   'they',
#   'have',
#   'knowledgable',
#   'friendly',
#   'sales',
#   'staff',
#   'whatever',
#   'other',
#   'reason',
#   'would',
#   'like',
#   'business',
#   'with',
#   'them',
#   'which',
#   'will',
#   'aggrigate',
#   'keep',
#   'them',
#   'business',
#   'available',
#   'fill',
#   'your',
#   'future',
#   'needs',
#   'they',
#   'charge',
#   'more',
#   'item',
#   'than',
#   'another',
#   'store',
#   'usually',
#   'purchase',
#   'item',
#   'store',
#   'your',
#   'choice',
#   'lowest',
#   'legitimate',
#   'price',
#   'being',
#   'offered',
#   'elsewhere',
#   'sounds',
#   'pretty',
#   'lame',
#   'understand',
#   'your',
#   'friends',
#   'charge',
#   'extra',
#   'just',
#   'much',
#   'usually',
#   'have',
#   'little',
#   'friendliness',
#   'seems',
#   'like',
#   'being',
#   'serviced',
#   'some',
#   'friendly',
#   'sales',
#   'people',
#   'robert',
#   'emmons',
#   'never',
#   'hesitate',
#   'sacrifice',
#   'clarity',
#   'calcshop',
#   'maintainability',
#   'save',
#   'precious',
#   'remmons',
#   'holonet',
#   'picoseconds',
#   'during',
#   'program',
#   'execution'],
#  ['from',
#   'hades',
#   'coos',
#   'dartmouth',
#   'brian',
#   'hughes',
#   'subject',
#   'apple',
#   'ergo',
#   'mouse',
#   'reply',
#   'hades',
#   'dartmouth',
#   'organization',
#   'dartmouth',
#   'college',
#   'hanover',
#   'disclaimer',
#   'personally',
#   'really',
#   'care',
#   'think',
#   'speak',
#   'moderator',
#   'arts',
#   'comics',
#   'info',
#   'lines',
#   'nwcs',
#   'utkvx',
#   'schizophrenia',
#   'means',
#   'never',
#   'being',
#   'alone',
#   'writes',
#   'does',
#   'anyone',
#   'know',
#   'open',
#   'apple',
#   'ergo',
#   'mouse',
#   'mouse',
#   'mine',
#   'lives',
#   'near',
#   'true',
#   'really',
#   'picks',
#   'from',
#   'what',
#   'tell',
#   'looks',
#   'like',
#   'apple',
#   'welded',
#   'shut',
#   'must',
#   'have',
#   'tried',
#   'very',
#   'hard',
#   'just',
#   'opend',
#   'mine',
#   'about',
#   'seconds',
#   'take',
#   'look',
#   'bottom',
#   'dial',
#   'that',
#   'turns',
#   'open',
#   'much',
#   'like',
#   'older',
#   'mouses',
#   'used',
#   'have',
#   'harder',
#   'turn',
#   'first',
#   'quite',
#   'simple',
#   'open',
#   'also',
#   'does',
#   'anyone',
#   'know',
#   'about',
#   'installing',
#   'fpus',
#   'heard',
#   'some',
#   'people',
#   'saying',
#   'fried',
#   'motherboard',
#   'well',
#   'match',
#   'pins',
#   'correctly',
#   'will',
#   'have',
#   'some',
#   'problems',
#   'close',
#   'look',
#   'socket',
#   'should',
#   'give',
#   'idea',
#   'proper',
#   'orientation',
#   'chip',
#   'hades'],
#  ['from',
#   'rvpst2',
#   'pitt',
#   'richard',
#   'polinski',
#   'subject',
#   'winning',
#   'streaks',
#   'organization',
#   'university',
#   'pittsburgh',
#   'lines',
#   'article',
#   '93105',
#   '053748rap115',
#   'psuvm',
#   'rap115',
#   'psuvm',
#   'robbie',
#   'writes',
#   'penguins',
#   'game',
#   'unbeaten',
#   'streak',
#   'carries',
#   'over',
#   'next',
#   'season',
#   'meaning',
#   'they',
#   'start',
#   'season',
#   'with',
#   'another',
#   'game',
#   'unbeaten',
#   'streak',
#   'they',
#   'will',
#   'have',
#   'eclipsed',
#   'flyers',
#   'record',
#   'right',
#   'penguins',
#   'game',
#   'winning',
#   'streak',
#   'streaks',
#   'carry',
#   'over',
#   'from',
#   'year',
#   'another',
#   'hmmmm',
#   'sure',
#   'this',
#   'true',
#   'according',
#   'mike',
#   'lang',
#   'good',
#   'stagie',
#   'along',
#   'with',
#   'rest',
#   'crews',
#   'pittsburgh',
#   'they',
#   'winning',
#   'streak',
#   'could',
#   'have',
#   'stopped',
#   'because',
#   'regular',
#   'season',
#   'mark',
#   'would',
#   'think',
#   'this',
#   'would',
#   'also',
#   'hold',
#   'with',
#   'unbeaten',
#   'streak',
#   'regular',
#   'season',
#   'games',
#   'however',
#   'right',
#   'that',
#   'playoff',
#   'streak',
#   'does',
#   'carry',
#   'over',
#   'from',
#   'last',
#   'year',
#   'with',
#   'more',
#   'believe',
#   'they',
#   'edmonton',
#   'record',
#   'quote',
#   'that',
#   'robbie',
#   'penguins',
#   'easy',
#   'contact',
#   'stanley',
#   'will',
#   'have',
#   'greater',
#   'rewards',
#   'penn',
#   'state',
#   'lady',
#   'lions',
#   'champions',
#   'mountains',
#   'valleys',
#   'rap115',
#   'psuvm',
#   'straight',
#   'wins',
#   'better',
#   'than',
#   'nothing'],
#  ['from',
#   'domain',
#   'cbnewsf',
#   'george',
#   'hodge',
#   'subject',
#   'dayton',
#   'hamfest',
#   'summary',
#   'where',
#   'when',
#   'dayton',
#   'hamfest',
#   'organization',
#   'distribution',
#   'lines',
#   'some',
#   'weeks',
#   'someone',
#   'posted',
#   'article',
#   'telling',
#   'when',
#   'where',
#   'hamfest',
#   'computerfest',
#   'going',
#   'help',
#   'dayton',
#   'unfortunately',
#   'lost',
#   'article',
#   'wondering',
#   'someone',
#   'could',
#   'repost',
#   'believe',
#   'being',
#   'held',
#   'this',
#   'month',
#   'dayton',
#   'convention',
#   'center',
#   'sure',
#   'help',
#   'more',
#   'details',
#   'would',
#   'greatly',
#   'appreciated',
#   'george',
#   'hodge',
#   'domain',
#   'cbcat'],
#  ['from',
#   'caltech',
#   'kevin',
#   'plaxco',
#   'subject',
#   'boom',
#   'whoosh',
#   'organization',
#   'california',
#   'institute',
#   'technology',
#   'pasadena',
#   'lines',
#   'nntp',
#   'posting',
#   'host',
#   'sgi1',
#   'caltech',
#   'article',
#   '37147',
#   'scicom',
#   'alphacdc',
#   'wats',
#   'scicom',
#   'alphacdc',
#   'bruce',
#   'watson',
#   'writes',
#   'pageos',
#   'echo',
#   'balloons',
#   'were',
#   'inflated',
#   'with',
#   'substance',
#   'which',
#   'expanded',
#   'vacuum',
#   'called',
#   'once',
#   'inflated',
#   'substance',
#   'longer',
#   'needed',
#   'since',
#   'there',
#   'nothing',
#   'cause',
#   'balloon',
#   'collapse',
#   'this',
#   'inflatable',
#   'structure',
#   'could',
#   'suffer',
#   'multiple',
#   'holes',
#   'with',
#   'disastrous',
#   'deflation',
#   'balloons',
#   'were',
#   'sufficiently',
#   'orbit',
#   'that',
#   'they',
#   'experienced',
#   'some',
#   'resistance',
#   'when',
#   'they',
#   'were',
#   'finally',
#   'punctured',
#   'this',
#   'preasure',
#   'internal',
#   'preasure',
#   'that',
#   'needed',
#   'maintain',
#   'spherical',
#   'shape',
#   'against',
#   'this',
#   'resistance',
#   'caused',
#   'them',
#   'catastrophically',
#   'deflated',
#   'large',
#   'silvered',
#   'shards',
#   'that',
#   'remained',
#   'were',
#   'easily',
#   'visible',
#   'some',
#   'time',
#   'before',
#   'reentry',
#   'though',
#   'longer',
#   'useful',
#   'passive',
#   'transponder',
#   'billboard',
#   'should',
#   'like',
#   'dime',
#   'store',
#   'balloon'],
#  ['from',
#   'richard',
#   'stueven',
#   'subject',
#   'octopus',
#   'detroit',
#   'reply',
#   'organization',
#   'wind',
#   'river',
#   'systems',
#   'lines',
#   'nntp',
#   'posting',
#   'host',
#   'gakbox',
#   'have',
#   'richard',
#   'stueven',
#   '22584',
#   'erected',
#   'multitude',
#   'internet',
#   'offices',
#   'sent',
#   'hither',
#   'swarms',
#   'attmail',
#   'attmail',
#   'gakhaus',
#   'sharx',
#   'officers',
#   'harass',
#   'people',
#   'palace',
#   'their',
#   'substance'],
#  ['from',
#   'ibeshir',
#   'ibrahim',
#   'subject',
#   'terminal',
#   'sale',
#   'organization',
#   'public',
#   'access',
#   'unix',
#   'denver',
#   'math',
#   'dept',
#   'distribution',
#   'lines',
#   'have',
#   'vt200',
#   'vt100',
#   'compatible',
#   'terminal',
#   'with',
#   '1200',
#   'external',
#   'hyess',
#   'modem',
#   'amber',
#   'screens',
#   'keyboard',
#   'cable',
#   'make',
#   'offer'],
#  ['from',
#   'anwar',
#   'anwar',
#   'mohammed',
#   'subject',
#   'remember',
#   'those',
#   'names',
#   'come',
#   'election',
#   'time',
#   'keywords',
#   'federal',
#   'government',
#   'international',
#   'government',
#   'nntp',
#   'posting',
#   'host',
#   'gs135',
#   'organization',
#   'school',
#   'computer',
#   'science',
#   'carnegie',
#   'mellon',
#   'lines',
#   'article',
#   'c5u4qi',
#   'apollo',
#   'nelson_p',
#   'apollo',
#   'peter',
#   'nelson',
#   'writes',
#   'with',
#   'bosnia',
#   'large',
#   'moslem',
#   'population',
#   'have',
#   'nations',
#   'like',
#   'turkey',
#   'saudi',
#   'arabia',
#   'syria',
#   'egypt',
#   'others',
#   'with',
#   'either',
#   'money',
#   'strong',
#   'military',
#   'forces',
#   'spoken',
#   'more',
#   'forcibly',
#   'offered',
#   'help',
#   'bosnia',
#   'obviously',
#   'really',
#   'know',
#   'they',
#   'have',
#   'spoken',
#   'state',
#   'christopher',
#   'recent',
#   'trip',
#   'they',
#   'have',
#   'provided',
#   'millions',
#   'they',
#   'have',
#   'participated',
#   'airlifts',
#   'sarajevo',
#   'they',
#   'would',
#   'supply',
#   'military',
#   'would',
#   'lift',
#   'embargo',
#   'arms',
#   'sales',
#   'turkish',
#   'ambassador',
#   'ocassionally',
#   'said',
#   'thing',
#   'that',
#   'great',
#   'enthusism',
#   'from',
#   'those',
#   'places',
#   'their',
#   'hands',
#   'dirty',
#   'does',
#   'always',
#   'stuck',
#   'with',
#   'this',
#   'stuff',
#   'above',
#   'kuwait',
#   'directly',
#   'participated',
#   'airlift',
#   'food',
#   'sarajevo',
#   'besides',
#   'there',
#   'case',
#   'that',
#   'made',
#   'military',
#   'involvement',
#   'there',
#   'that',
#   'doesn',
#   'apply',
#   'equally',
#   'well',
#   'liberia',
#   'angola',
#   'appears',
#   'with',
#   'khmer',
#   'rouge',
#   'campaign',
#   'cambodia',
#   'whites',
#   'count',
#   'some',
#   'might',
#   'kuwaitis',
#   'white',
#   'ooops',
#   'forgot',
#   'kuwaitis',
#   'rich',
#   'loaded',
#   'with',
#   'petro',
#   'dollars',
#   'they',
#   'count',
#   'peter'],
#  ['from',
#   'djcohen',
#   'yalevm',
#   'yale',
#   'daniel',
#   'cohen',
#   'subject',
#   'interesting',
#   'behaviour',
#   'c650',
#   'nntp',
#   'posting',
#   'host',
#   'yalevm',
#   'yale',
#   'organization',
#   'yale',
#   'university',
#   'lines',
#   'article',
#   '1993apr15',
#   '181440',
#   '15490',
#   'waikato',
#   'waikato',
#   'lawrence',
#   'oliveiro',
#   'waikato',
#   'university',
#   'writes',
#   'noticed',
#   'interesting',
#   'phenomenon',
#   'centris',
#   'unplug',
#   'keyboard',
#   'mouse',
#   'plug',
#   'them',
#   'again',
#   'without',
#   'turning',
#   'power',
#   'mouse',
#   'suddenly',
#   'switches',
#   'about',
#   'half',
#   'normal',
#   'movement',
#   'speed',
#   'check',
#   'mouse',
#   'control',
#   'panel',
#   'there',
#   'change',
#   'setting',
#   'there',
#   'still',
#   'full',
#   'speed',
#   'like',
#   'restarting',
#   'machine',
#   'restores',
#   'normal',
#   'mouse',
#   'speed',
#   'happens',
#   'with',
#   'both',
#   'newer',
#   'style',
#   'mouse',
#   'that',
#   'came',
#   'with',
#   'centris',
#   'older',
#   'style',
#   'mouse',
#   'from',
#   'iifx',
#   'work',
#   'thus',
#   'think',
#   'anything',
#   'with',
#   'resolution',
#   'setting',
#   'mouse',
#   'definitely',
#   'quirk',
#   'interface',
#   'either',
#   'hardware',
#   'software',
#   'centris',
#   'itself',
#   'have',
#   'noticed',
#   'this',
#   'exact',
#   'same',
#   'phenomenon',
#   'occurs',
#   'with',
#   'lciii',
#   'perhaps',
#   'quirk',
#   'machines'],
#  ['from',
#   'pitt',
#   'gordon',
#   'banks',
#   'subject',
#   'request',
#   'information',
#   'essential',
#   'tremor',
#   'indrol',
#   'reply',
#   'pitt',
#   'gordon',
#   'banks',
#   'organization',
#   'univ',
#   'pittsburgh',
#   'computer',
#   'science',
#   'lines',
#   'article',
#   '1q1tbninnnfn',
#   'life',
#   'sundar',
#   'writes',
#   'essential',
#   'tremor',
#   'progressive',
#   'hereditary',
#   'tremor',
#   'that',
#   'gets',
#   'worse',
#   'when',
#   'patient',
#   'tries',
#   'effected',
#   'member',
#   'limbs',
#   'vocal',
#   'cords',
#   'head',
#   'involved',
#   'inderal',
#   'beta',
#   'blocker',
#   'usually',
#   'effective',
#   'diminishing',
#   'tremor',
#   'alcohol',
#   'mysoline',
#   'also',
#   'effective',
#   'alcohol',
#   'toxic',
#   'treatment',
#   'gordon',
#   'banks',
#   'n3jxp',
#   'skepticism',
#   'chastity',
#   'intellect',
#   'cadre',
#   'pitt',
#   'shameful',
#   'surrender',
#   'soon'],
#  ['from',
#   'dxf12',
#   'cwru',
#   'douglas',
#   'fowler',
#   'subject',
#   'christian',
#   'parenting',
#   'organization',
#   'case',
#   'western',
#   'reserve',
#   'university',
#   'cleveland',
#   'ohio',
#   'lines',
#   'sorry',
#   'posting',
#   'this',
#   'mail',
#   'keeps',
#   'bouncing',
#   'maybe',
#   'will',
#   'help',
#   'others',
#   'here',
#   'anyway',
#   'therefore',
#   'pray',
#   'others',
#   'will',
#   'read',
#   'this',
#   'actually',
#   'response',
#   'from',
#   'aunt',
#   'kids',
#   'since',
#   'have',
#   'none',
#   'sociology',
#   'student',
#   'currently',
#   'researching',
#   'into',
#   'young',
#   'offenders',
#   'looking',
#   'various',
#   'groups',
#   'children',
#   'raised',
#   'home',
#   'moment',
#   'formlulating',
#   'information',
#   'discipline',
#   'within',
#   'christian',
#   'home',
#   'please',
#   'parent',
#   'this',
#   'catagory',
#   'email',
#   'your',
#   'response',
#   'following',
#   'questionaire',
#   'responses',
#   'will',
#   'treated',
#   'confidentially',
#   'will',
#   'only',
#   'used',
#   'prepare',
#   'stats',
#   'posting',
#   'this',
#   'good',
#   'christian',
#   'relative',
#   'does',
#   'have',
#   'mail',
#   'access',
#   'since',
#   'this',
#   'aunt',
#   'uncle',
#   'have',
#   'kids',
#   'felt',
#   'they',
#   'would',
#   'more',
#   'relevant',
#   'than',
#   'have',
#   'none',
#   'ages',
#   'sexes',
#   'children',
#   'year',
#   '13yo',
#   'twins',
#   '10yo',
#   'girl',
#   'spank',
#   'your',
#   'kids',
#   'call',
#   'spanking',
#   'they',
#   'very',
#   'rarely',
#   'often',
#   'call',
#   'spanking',
#   'because',
#   'more',
#   'reaction',
#   'something',
#   'very',
#   'dangerous',
#   'such',
#   'trying',
#   'stick',
#   'their',
#   'finger',
#   'running',
#   'into',
#   'road',
#   'maybe',
#   'times',
#   'each',
#   'except',
#   'girl',
#   'been',
#   'spanked',
#   'they',
#   'call',
#   'that',
#   'because',
#   'does',
#   'hurt',
#   'their',
#   'feelings',
#   'course',
#   'give',
#   'hugs',
#   'stuff',
#   'ensure',
#   'they',
#   'know',
#   'they',
#   'still',
#   'loved',
#   'implement',
#   'spank',
#   'with',
#   'that',
#   'would',
#   'painful',
#   'traumatic',
#   'they',
#   'never',
#   'recall',
#   'they',
#   'were',
#   'punished',
#   'besides',
#   'must',
#   'immediate',
#   'taking',
#   'time',
#   'toolmeans',
#   'doing',
#   'right',
#   'away',
#   'that',
#   'lessens',
#   'impact',
#   'very',
#   'emotional',
#   'child',
#   'which',
#   'evidenced',
#   'fact',
#   'that',
#   'little',
#   'slap',
#   'rear',
#   'which',
#   'hurts',
#   'perhaps',
#   'seconds',
#   'called',
#   'spanking',
#   'spank',
#   'what',
#   'method',
#   'discipline',
#   'lots',
#   'logical',
#   'consequences',
#   'instance',
#   'when',
#   'matthew',
#   'dared',
#   'good',
#   'friend',
#   'jump',
#   'treehouse',
#   'would',
#   'push',
#   'made',
#   'sure',
#   'they',
#   'didn',
#   'play',
#   'together',
#   'days',
#   'know',
#   'that',
#   'would',
#   'make',
#   'lose',
#   'friends',
#   'very',
#   'quickly',
#   'never',
#   'done',
#   'anything',
#   'like',
#   'that',
#   'since',
#   'also',
#   'time',
#   'their',
#   'rooms',
#   'timer',
#   'they',
#   'keep',
#   'arguing',
#   'with',
#   'over',
#   'leaving',
#   'since',
#   'hard',
#   'argue',
#   'with',
#   'macine',
#   'will',
#   'closed',
#   'door',
#   'tell',
#   'them',
#   'timeout',
#   'over',
#   'until',
#   'they',
#   'calm',
#   'down',
#   'they',
#   'tantrumy',
#   'stairs',
#   'when',
#   'they',
#   'really',
#   'young',
#   'your',
#   'your',
#   'location',
#   'bath',
#   'ohio',
#   'right',
#   'outside',
#   'akron',
#   'northeast',
#   'part',
#   'ohio',
#   'while',
#   'under',
#   'ever',
#   'commit',
#   'criminal',
#   'offence',
#   'none',
#   'kids',
#   'would',
#   'dream',
#   'hope',
#   'this',
#   'teach',
#   'parents',
#   'that',
#   'physical',
#   'punishment',
#   'always',
#   'required',
#   'parents',
#   'that',
#   'excuse',
#   'hard',
#   'disciplined',
#   'lots',
#   'timeouts',
#   'same',
#   'family',
#   'husband',
#   'have',
#   'never',
#   'used',
#   'spankings',
#   'fact',
#   'grandmother',
#   'kids',
#   'they',
#   'were',
#   'almost',
#   'never',
#   'spanked',
#   'this',
#   'around',
#   'turn',
#   'century',
#   'none',
#   'ever',
#   'been',
#   'afoul',
#   'made',
#   'jesus',
#   'says',
#   'referring',
#   'small',
#   'child',
#   'whom',
#   'holding',
#   'that',
#   'what',
#   'least',
#   'these',
#   'also',
#   'bible',
#   'also',
#   'says',
#   'things',
#   'kind',
#   'merciful',
#   'especially',
#   'loving',
#   'colossians',
#   'there',
#   'room',
#   'selfish',
#   'anger',
#   'which',
#   'admit',
#   'been',
#   'tempted',
#   'with',
#   'times',
#   'when',
#   'felt',
#   'like',
#   'spanking',
#   'hard',
#   'anger',
#   'maybe',
#   'deserved',
#   'little',
#   'slap',
#   'rear',
#   'what',
#   'would',
#   'have',
#   'given',
#   'would',
#   'have',
#   'been',
#   'devil',
#   'work',
#   'could',
#   'feel',
#   'temptation',
#   'just',
#   'angrily',
#   'ordered',
#   'room',
#   'went',
#   'room',
#   'myself',
#   'after',
#   'praying',
#   'asking',
#   'forgiveness',
#   'much',
#   'calmer',
#   'feel',
#   'like',
#   'spanking',
#   'felt',
#   'that',
#   'what',
#   'done',
#   'enough',
#   'punishment',
#   'doug',
#   'fowler',
#   'dxf12',
#   'cwru',
#   'mommys',
#   'daddys',
#   'other',
#   'ever',
#   'wonder',
#   'after',
#   'casey',
#   'relatives',
#   'have',
#   'give',
#   'lots',
#   'hugs',
#   'love',
#   'missed',
#   'strike',
#   'poem',
#   'support',
#   'cause',
#   'heaven',
#   'just',
#   'great',
#   'first',
#   'made',
#   'that',
#   'lasts',
#   'forever',
#   'ever'],
#  ...]

# %%
MAX_DF = 0.8
MIN_COUNT = 5
vocabulary, word_doc_freq = build_vocabulary(train_tokenized, max_doc_freq=MAX_DF, min_count=MIN_COUNT)
UNIQUE_WORDS_N = len(vocabulary)
print('Количество уникальных токенов', UNIQUE_WORDS_N)
print(list(vocabulary.items())[:10])
# Out:
# Количество уникальных токенов 21628
# [('that', 0), ('this', 1), ('have', 2), ('with', 3), ('writes', 4), ('article', 5), ('posting', 6), ('host', 7), ('nntp', 8), ('there', 9)]

# %%
plt.hist(word_doc_freq, bins=20)
plt.title('Распределение относительных частот слов')
plt.yscale('log');

# %%
VECTORIZATION_MODE = 'tfidf'
train_vectors = vectorize_texts(train_tokenized, vocabulary, word_doc_freq, mode=VECTORIZATION_MODE)
test_vectors = vectorize_texts(test_tokenized, vocabulary, word_doc_freq, mode=VECTORIZATION_MODE)

print('Размерность матрицы признаков обучающей выборки', train_vectors.shape)
print('Размерность матрицы признаков тестовой выборки', test_vectors.shape)
print()
print('Количество ненулевых элементов в обучающей выборке', train_vectors.nnz)
print('Процент заполненности матрицы признаков {:.2f}%'.format(train_vectors.nnz * 100 / (train_vectors.shape[0] * train_vectors.shape[1])))
print()
print('Количество ненулевых элементов в тестовой выборке', test_vectors.nnz)
print('Процент заполненности матрицы признаков {:.2f}%'.format(test_vectors.nnz * 100 / (test_vectors.shape[0] * test_vectors.shape[1])))
# Out:
# Размерность матрицы признаков обучающей выборки (11314, 21628)
# Размерность матрицы признаков тестовой выборки (7532, 21628)
#
# Количество ненулевых элементов в обучающей выборке 1126792
# Процент заполненности матрицы признаков 0.46%
#
# Количество ненулевых элементов в тестовой выборке 721529
# Процент заполненности матрицы признаков 0.44%

# %%
plt.hist(train_vectors.data, bins=20)
plt.title('Распределение весов признаков')
plt.yscale('log');

# %% [markdown]
# ### Распределение классов

# %%
UNIQUE_LABELS_N = len(set(train_source['target']))
print('Количество уникальных меток', UNIQUE_LABELS_N)
# Out:
# Количество уникальных меток 20

# %%
plt.hist(train_source['target'], bins=np.arange(0, 21))
plt.title('Распределение меток в обучающей выборке');

# %%
plt.hist(test_source['target'], bins=np.arange(0, 21))
plt.title('Распределение меток в тестовой выборке');

# %% [markdown]
# ### PyTorch Dataset

# %%
train_dataset = SparseFeaturesDataset(train_vectors, train_source['target'])
test_dataset = SparseFeaturesDataset(test_vectors, test_source['target'])

# %% [markdown]
# ## Обучение модели на PyTorch

# %%
model = nn.Linear(UNIQUE_WORDS_N, UNIQUE_LABELS_N)

scheduler = lambda optim: \
    torch.optim.lr_scheduler.ReduceLROnPlateau(optim, patience=5, factor=0.5, verbose=True)

best_val_loss, best_model = train_eval_loop(model=model,
                                            train_dataset=train_dataset,
                                            val_dataset=test_dataset,
                                            criterion=F.cross_entropy,
                                            lr=1e-1,
                                            epoch_n=200,
                                            batch_size=32,
                                            l2_reg_alpha=0,
                                            lr_scheduler_ctor=scheduler)
# Out:
# Эпоха 0
# Эпоха: 354 итераций, 7.85 сек
# Среднее значение функции потерь на обучении 2.2337176126275358
# Среднее значение функции потерь на валидации 2.112866316811513
# Новая лучшая модель!
#
# Эпоха 1
# Эпоха: 354 итераций, 6.85 сек
# Среднее значение функции потерь на обучении 0.9168939716735128
# Среднее значение функции потерь на валидации 1.685059588339369
# Новая лучшая модель!
#
# Эпоха 2
# Эпоха: 354 итераций, 5.13 сек
# Среднее значение функции потерь на обучении 0.4672870793416675
# Среднее значение функции потерь на валидации 1.4720147519798603
# Новая лучшая модель!
#
# Эпоха 3
# Эпоха: 354 итераций, 4.86 сек
# Среднее значение функции потерь на обучении 0.2839005882878088
# Среднее значение функции потерь на валидации 1.3453914785789232
# Новая лучшая модель!
#
# Эпоха 4
# Эпоха: 354 итераций, 5.40 сек
# Среднее значение функции потерь на обучении 0.1913678102026888
# Среднее значение функции потерь на валидации 1.264681026592093
# Новая лучшая модель!
#
# Эпоха 5
# Эпоха: 354 итераций, 4.95 сек
# Среднее значение функции потерь на обучении 0.13675852084143014
# Среднее значение функции потерь на валидации 1.2028922221418155
# Новая лучшая модель!
#
# Эпоха 6
# Эпоха: 354 итераций, 10.21 сек
# Среднее значение функции потерь на обучении 0.10193788150777924
# Среднее значение функции потерь на валидации 1.1508161372552483
# Новая лучшая модель!
#
# Эпоха 7
# Эпоха: 354 итераций, 5.89 сек
# Среднее значение функции потерь на обучении 0.07842435812482894
# Среднее значение функции потерь на валидации 1.117952748122862
# Новая лучшая модель!
#
# Эпоха 8
# Эпоха: 354 итераций, 5.14 сек
# Среднее значение функции потерь на обучении 0.061747324516165394
# Среднее значение функции потерь на валидации 1.0876960736715187
# Новая лучшая модель!
#
# Эпоха 9
# Эпоха: 354 итераций, 5.86 сек
# Среднее значение функции потерь на обучении 0.049388273892724245
# Среднее значение функции потерь на валидации 1.0663741857318554
# Новая лучшая модель!
#
# Эпоха 10
# Эпоха: 354 итераций, 5.10 сек
# Среднее значение функции потерь на обучении 0.040295586860765
# Среднее значение функции потерь на валидации 1.0410578980789347
# Новая лучшая модель!
#
# Эпоха 11
# Эпоха: 354 итераций, 6.36 сек
# Среднее значение функции потерь на обучении 0.03305259203317307
# Среднее значение функции потерь на валидации 1.02875507105205
# Новая лучшая модель!
#
# Эпоха 12
# Эпоха: 354 итераций, 7.76 сек
# Среднее значение функции потерь на обучении 0.027425217444845343
# Среднее значение функции потерь на валидации 1.0075337583735837
# Новая лучшая модель!
#
# Эпоха 13
# Эпоха: 354 итераций, 4.70 сек
# Среднее значение функции потерь на обучении 0.022951851859373058
# Среднее значение функции потерь на валидации 1.0053895497221057
# Новая лучшая модель!
#
# Эпоха 14
# Эпоха: 354 итераций, 5.77 сек
# Среднее значение функции потерь на обучении 0.01957615943215156
# Среднее значение функции потерь на валидации 0.9912299458253182
# Новая лучшая модель!
#
# Эпоха 15
# Эпоха: 354 итераций, 6.07 сек
# Среднее значение функции потерь на обучении 0.0166682599935849
# Среднее значение функции потерь на валидации 0.9763237418512166
# Новая лучшая модель!
#
# Эпоха 16
# Эпоха: 354 итераций, 6.51 сек
# Среднее значение функции потерь на обучении 0.014235745190700652
# Среднее значение функции потерь на валидации 0.9738781294327671
# Новая лучшая модель!
#
# Эпоха 17
# Эпоха: 354 итераций, 5.43 сек
# Среднее значение функции потерь на обучении 0.012445640253655528
# Среднее значение функции потерь на валидации 0.9628991972086793
# Новая лучшая модель!
#
# Эпоха 18
# Эпоха: 354 итераций, 6.75 сек
# Среднее значение функции потерь на обучении 0.010661981722318942
# Среднее значение функции потерь на валидации 0.9621253578087031
# Новая лучшая модель!
#
# Эпоха 19
# Эпоха: 354 итераций, 5.94 сек
# Среднее значение функции потерь на обучении 0.009327932312232206
# Среднее значение функции потерь на валидации 0.9496989823498968
# Новая лучшая модель!
#
# Эпоха 20
# Эпоха: 354 итераций, 5.95 сек
# Среднее значение функции потерь на обучении 0.008168927520792405
# Среднее значение функции потерь на валидации 0.9458824238282139
# Новая лучшая модель!
#
# Эпоха 21
# Эпоха: 354 итераций, 5.22 сек
# Среднее значение функции потерь на обучении 0.007445805468320278
# Среднее значение функции потерь на валидации 0.9433437710848905
# Новая лучшая модель!
#
# Эпоха 22
# Эпоха: 354 итераций, 5.46 сек
# Среднее значение функции потерь на обучении 0.006696797284826447
# Среднее значение функции потерь на валидации 0.9505911860930718
#
# Эпоха 23
# Эпоха: 354 итераций, 5.95 сек
# Среднее значение функции потерь на обучении 0.0058198579091126214
# Среднее значение функции потерь на валидации 0.9628231197090472
#
# Эпоха 24
# Эпоха: 354 итераций, 5.14 сек
# Среднее значение функции потерь на обучении 0.005048878554887491
# Среднее значение функции потерь на валидации 0.9306997270402262
# Новая лучшая модель!
#
# Эпоха 25
# Эпоха: 354 итераций, 5.39 сек
# Среднее значение функции потерь на обучении 0.005005691282051263
# Среднее значение функции потерь на валидации 0.9506561987228312
#
# Эпоха 26
# Эпоха: 354 итераций, 5.79 сек
# Среднее значение функции потерь на обучении 0.004342270440370697
# Среднее значение функции потерь на валидации 0.9557858200396522
#
# Эпоха 27
# Эпоха: 354 итераций, 5.34 сек
# Среднее значение функции потерь на обучении 0.004094741202458097
# Среднее значение функции потерь на валидации 0.942077911885108
#
# Эпоха 28
# Эпоха: 354 итераций, 4.69 сек
# Среднее значение функции потерь на обучении 0.0038677649873395657
# Среднее значение функции потерь на валидации 0.9360140789363344
#
# Эпоха 29
# Эпоха: 354 итераций, 4.86 сек
# Среднее значение функции потерь на обучении 0.0035807604008317416
# Среднее значение функции потерь на валидации 0.9544134653978429
#
# Эпоха 30
# Эпоха: 354 итераций, 4.71 сек
# Среднее значение функции потерь на обучении 0.003029995916807882
# Среднее значение функции потерь на валидации 0.9511191800741826
# Epoch    31: reducing learning rate of group 0 to 5.0000e-02.
#
# Эпоха 31
# Эпоха: 354 итераций, 4.95 сек
# Среднее значение функции потерь на обучении 0.0027071122983786263
# Среднее значение функции потерь на валидации 0.9415778318199061
#
# Эпоха 32
# Эпоха: 354 итераций, 4.80 сек
# Среднее значение функции потерь на обучении 0.0025801401484874735
# Среднее значение функции потерь на валидации 0.9425835002024295
#
# Эпоха 33
# Эпоха: 354 итераций, 5.30 сек
# Среднее значение функции потерь на обучении 0.0026589979808632875
# Среднее значение функции потерь на валидации 0.9346174597740173
#
# Эпоха 34
# Эпоха: 354 итераций, 4.83 сек
# Среднее значение функции потерь на обучении 0.0024470082980923955
# Среднее значение функции потерь на валидации 0.9388271211567571
#
# Эпоха 35
# Эпоха: 354 итераций, 4.76 сек
# Среднее значение функции потерь на обучении 0.0023502390698110815
# Среднее значение функции потерь на валидации 0.9430076761518494
# Модель не улучшилась за последние 10 эпох, прекращаем обучение

# %% [markdown]
# ## Оценка качества

# %%
train_pred = predict_with_model(best_model, train_dataset)

train_loss = F.cross_entropy(torch.from_numpy(train_pred),
                             torch.from_numpy(train_source['target']).long())

print('Среднее значение функции потерь на обучении', float(train_loss))
print('Доля верных ответов', accuracy_score(train_source['target'], train_pred.argmax(-1)))
print()



test_pred = predict_with_model(best_model, test_dataset)

test_loss = F.cross_entropy(torch.from_numpy(test_pred),
                            torch.from_numpy(test_source['target']).long())

print('Среднее значение функции потерь на валидации', float(test_loss))
print('Доля верных ответов', accuracy_score(test_source['target'], test_pred.argmax(-1)))
# Out:
# 100%|██████████| 354/353.5625 [00:02<00:00, 126.20it/s]
#   6%|▌         | 14/235.375 [00:00<00:01, 131.98it/s]
# Среднее значение функции потерь на обучении 0.004174976609647274
# Доля верных ответов 0.9992929114371575
# 236it [00:01, 129.56it/s]
# Среднее значение функции потерь на валидации 0.928877592086792
# Доля верных ответов 0.7712426978226234

# %% [markdown]
# # Альтернативная реализация на scikit-learn

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

sklearn_pipeline = Pipeline((('vect', TfidfVectorizer(tokenizer=tokenize_text_simple_regex,
                                                      max_df=MAX_DF,
                                                      min_df=MIN_COUNT)),
                             ('cls', LogisticRegression())))
sklearn_pipeline.fit(train_source['data'], train_source['target']);

# %% [markdown]
# ## Оценка качества

# %%
sklearn_train_pred = sklearn_pipeline.predict_proba(train_source['data'])
sklearn_train_loss = F.cross_entropy(torch.from_numpy(sklearn_train_pred),
                                                 torch.from_numpy(train_source['target']).long())
print('Среднее значение функции потерь на обучении', float(sklearn_train_loss))
print('Доля верных ответов', accuracy_score(train_source['target'], sklearn_train_pred.argmax(-1)))
print()

sklearn_test_pred = sklearn_pipeline.predict_proba(test_source['data'])
sklearn_test_loss = F.cross_entropy(torch.from_numpy(sklearn_test_pred),
                                                torch.from_numpy(test_source['target']).long())
print('Среднее значение функции потерь на валидации', float(sklearn_test_loss))
print('Доля верных ответов', accuracy_score(test_source['target'], sklearn_test_pred.argmax(-1)))
# Out:
# Среднее значение функции потерь на обучении 2.495478891870249
# Доля верных ответов 0.9716280714159449
#
# Среднее значение функции потерь на валидации 2.653902258244267
# Доля верных ответов 0.8190387679235263
